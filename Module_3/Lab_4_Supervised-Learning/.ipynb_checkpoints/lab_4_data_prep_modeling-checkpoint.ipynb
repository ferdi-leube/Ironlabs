# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# In this lab, we will explore a dataset that describes websites with different features and labels them either benign or malicious . We will use supervised learning algorithms to figure out what feature patterns malicious websites are likely to have and use our model to predict malicious websites.
#
# # Challenge 1 - Explore The Dataset
#
# Let's start by exploring the dataset. First load the data file:

# %%
websites = pd.read_csv(r"C:\Users\leube\Ironhack\cloned_labs\module_3\Lab_4_Supervised-Learning\website.csv")

# %% [markdown]
# #### Explore the data from an bird's-eye view.
#
# You should already been very familiar with the procedures now so we won't provide the instructions step by step. Reflect on what you did in the previous labs and explore the dataset.
#
# Things you'll be looking for:
#
# * What the dataset looks like?
# * What are the data types?
# * Which columns contain the features of the websites?
# * Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# * Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
#
# Feel free to add additional cells for your explorations. Make sure to comment what you find out.

# %%
websites['WHOIS_UPDATED_DATE'].head(5)
# Out:
# 0               None
# 1               None
# 2               None
# 3    12/09/2013 0:45
# 4    11/04/2017 0:00
# Name: WHOIS_UPDATED_DATE, dtype: object

# %%
websites.shape
# Out:
# (1781, 21)

# %%
# Your code here
websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1781 non-null   object
#  4   SERVER                     1780 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1781 non-null   object
#  7   WHOIS_STATEPRO             1781 non-null   object
#  8   WHOIS_REGDATE              1781 non-null   object
#  9   WHOIS_UPDATED_DATE         1781 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  12  REMOTE_IPS                 1781 non-null   int64
# ...

# %%
# TRANSFORM REGDATE AND UPDATEDDATE
# encode charset, country, url, server, state

# %%
encol = websites.select_dtypes(include=['object']).columns.tolist()
for x in encol:
    websites[x] = websites[x].str.lower()

# %%
allcoll =

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      m0_109          16                          7  iso-8859-1
# 1     b0_2314          16                          6       utf-8
# 2      b0_911          16                          6    us-ascii
# 3      b0_113          17                          6  iso-8859-1
# 4      b0_403          17                          6       utf-8
# ...       ...         ...                        ...         ...
# 1776    m4_48         194                         16       utf-8
# 1777    m4_41         198                         17       utf-8
# 1778   b0_162         201                         34       utf-8
# 1779  b0_1152         234                         34  iso-8859-1
# 1780   b0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          none           none
# ...

# %%
print(encol)
# Out:
# ['URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']

# %%
datet = '1/07/2016 0:00'
datet = '21/04/2017 16:47'
word = [x for x in datet]
datet[5:9]
word[5:9]
len(datet)
datet[6:10]
# Out:
# '2017'

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      m0_109          16                          7  iso-8859-1
# 1     b0_2314          16                          6       utf-8
# 2      b0_911          16                          6    us-ascii
# 3      b0_113          17                          6  iso-8859-1
# 4      b0_403          17                          6       utf-8
# ...       ...         ...                        ...         ...
# 1776    m4_48         194                         16       utf-8
# 1777    m4_41         198                         17       utf-8
# 1778   b0_162         201                         34       utf-8
# 1779  b0_1152         234                         34  iso-8859-1
# 1780   b0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          none           none
# ...

# %%
encol
# Out:
# ['URL',
#  'CHARSET',
#  'SERVER',
#  'WHOIS_COUNTRY',
#  'WHOIS_STATEPRO',
#  'WHOIS_REGDATE',
#  'WHOIS_UPDATED_DATE']

# %%
# bin dates
dates = encol[-2:]
for x in dates:
    lists = list(websites[x].unique())
    for y in lists:
        if len(y) == 14:
            year = y[5:9]
        elif len(y) >14:
            year = y[6:10]
        else:
            year = 'No date'
        print(year)
        websites[x].replace({y:year}, inplace=True)
# Out:
# 2015
# No date
# 1997
# 1996
# 016
# 2002
# 1997
# 2014
# 2007
# 2016
# 2002
# 2002
# 2000
# 2013
# 1999
# 2013
# 1999
# 2003
# 2008
# 2009
# 2002
# 2005
# 2005
# 2001
# 2008
# 2006
# 2000
# 2000
# 1999
# 1996
# 2008
# 1999
# 1997
# 2003
# 2008
# 2002
# 2005
# 2006
# 1996
# 1995
# 1998
# 2016
# 2011
# 2009
# 2002
# 1995
# 2007
# 1998
# 2005
# 2004
# 2008
# 2005
# 2006
# 2010
# 1997
# 2016
# 2016
# 2009
# 2009
# 000
# 2008
# 2000
# 2002
# 1997
# 2000
# 2002
# 2007
# 1997
# 2000
# 2009
# 2000
# 1998
# 2000
# 1999
# 2010
# 2000
# 1994
# 2010
# 2009
# 2015
# 2015
# 2017
# 2009
# 2010
# 1997
# 1996
# 2007
# 2004
# 3-20
# 1997
# 2008
# 1999
# 2004
# 1996
# 1995
# 2011
# 2016
# 000
# 2000
# 1999
# 2009
# 1998
# 1996
# 2007
# 2009
# 1995
# 2006
# 2007
# 2017
# 1996
# 2003
# 2015
# 2004
# 2004
# 2008
# 2003
# 010
# 2006
# 1998
# 1999
# 2003
# 2002
# 2006
# 1999
# 2015
# 2006
# 1996
# 2013
# 2003
# 1996
# 2016
# 1999
# 2001
# 1996
# 2004
# 1995
# 2014
# 1996
# 2000
# 1996
# 2000
# 2004
# 005
# ...

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      m0_109          16                          7  iso-8859-1
# 1     b0_2314          16                          6       utf-8
# 2      b0_911          16                          6    us-ascii
# 3      b0_113          17                          6  iso-8859-1
# 4      b0_403          17                          6       utf-8
# ...       ...         ...                        ...         ...
# 1776    m4_48         194                         16       utf-8
# 1777    m4_41         198                         17       utf-8
# 1778   b0_162         201                         34       utf-8
# 1779  b0_1152         234                         34  iso-8859-1
# 1780   b0_676         249                         40       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                      nginx           263.0          none           none
# ...

# %% [markdown]
# # cleaning dates complete

# %%
websites.describe()
# Out:
#         URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CONTENT_LENGTH  \
# count  1781.000000                1781.000000      969.000000
# mean     56.961258                  11.111735    11726.927761
# std      27.555586                   4.549896    36391.809051
# min      16.000000                   5.000000        0.000000
# 25%      39.000000                   8.000000      324.000000
# 50%      49.000000                  10.000000     1853.000000
# 75%      68.000000                  13.000000    11323.000000
# max     249.000000                  43.000000   649263.000000
#
#        TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT   REMOTE_IPS  \
# count                1781.000000           1781.000000  1781.000000
# mean                   16.261089              5.472768     3.060640
# std                    40.500975             21.807327     3.386975
# min                     0.000000              0.000000     0.000000
# ...

# %% [markdown]
# # deal with outliers

# %%
def delete_outliers(data, column_list, multiplier_IQR):
    for column in column_list:
        Q3 = data[column].quantile(0.75)
        Q1 = data[column].quantile(0.25)
        IQR = Q3 - Q1
        # cleaned = data[(data[column] > (Q3 + 1.5* IQR)) & (data[column] < (Q3 - 1.5* IQR))]
        data.drop(data[data[column] < (Q3 - multiplier_IQR* IQR)].index, inplace=True)
        data.drop(data[data[column] > (Q3 + multiplier_IQR* IQR)].index, inplace=True)
    return print('succes')

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

encolnum = websites.select_dtypes(include=numerics).columns.tolist()

# %%
encolnum.remove('Type')

# %%
delete_outliers(websites, encolnum, 3.5)
# Out:
# succes

# %%
websites
# Out:
#           URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0      m0_109          16                          7  iso-8859-1
# 1     b0_2314          16                          6       utf-8
# 2      b0_911          16                          6    us-ascii
# 3      b0_113          17                          6  iso-8859-1
# 5     b0_2064          18                          7       utf-8
# ...       ...         ...                        ...         ...
# 1763  b0_1361         149                         23  iso-8859-1
# 1764    m4_35         150                         26       utf-8
# 1766   b0_755         154                         21       utf-8
# 1769  b0_2237         161                         23  iso-8859-1
# 1770  b0_2099         169                         25       utf-8
#
#                       SERVER  CONTENT_LENGTH WHOIS_COUNTRY  WHOIS_STATEPRO  \
# 0                      nginx           263.0          none            none
# ...

# %% [markdown]
# # missing values

# %%
websites.isnull().sum()/len(websites)
# Out:
# URL                          0.0000
# URL_LENGTH                   0.0000
# NUMBER_SPECIAL_CHARACTERS    0.0000
# CHARSET                      0.0000
# SERVER                       0.0008
# CONTENT_LENGTH               0.4432
# WHOIS_COUNTRY                0.0000
# WHOIS_STATEPRO               0.0000
# WHOIS_REGDATE                0.0000
# WHOIS_UPDATED_DATE           0.0000
# TCP_CONVERSATION_EXCHANGE    0.0000
# DIST_REMOTE_TCP_PORT         0.0000
# REMOTE_IPS                   0.0000
# APP_BYTES                    0.0000
# SOURCE_APP_PACKETS           0.0000
# REMOTE_APP_PACKETS           0.0000
# SOURCE_APP_BYTES             0.0000
# REMOTE_APP_BYTES             0.0000
# APP_PACKETS                  0.0000
# DNS_QUERY_TIMES              0.0008
# Type                         0.0000
# dtype: float64

# %%
websites[['CONTENT_LENGTH','Type']].corr()

# no linear correlation, but doesnt mean that it has no impact, simply replacing all 50% not an option either, after further
# prep of data --> create two df one with replacement 'No data' one without and see if differenc in predictions
# Out:
#                 CONTENT_LENGTH  Type
# CONTENT_LENGTH             1.0   NaN
# Type                       NaN   NaN

# %%
# drop these two because only one row each
websites.drop(websites[websites['SERVER'].isnull()].index, inplace=True)

# %%
websites.drop(websites[websites['DNS_QUERY_TIMES'].isnull()].index, inplace=True)

# %%
websites.shape
# Out:
# (1248, 21)

# %%
# column content length to many missing, cant replace with 'Nothing' because it is numeric data
del websites['CONTENT_LENGTH']

# %%
websites.isnull().sum()
# Out:
# URL                          0
# URL_LENGTH                   0
# NUMBER_SPECIAL_CHARACTERS    0
# CHARSET                      0
# SERVER                       0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# WHOIS_UPDATED_DATE           0
# TCP_CONVERSATION_EXCHANGE    0
# DIST_REMOTE_TCP_PORT         0
# REMOTE_IPS                   0
# APP_BYTES                    0
# SOURCE_APP_PACKETS           0
# REMOTE_APP_PACKETS           0
# SOURCE_APP_BYTES             0
# REMOTE_APP_BYTES             0
# APP_PACKETS                  0
# DNS_QUERY_TIMES              0
# Type                         0
# dtype: int64

# %% [markdown]
# # check categorical data

# %% [markdown]
# #### Next, evaluate if the columns in this dataset are strongly correlated.
#
# In the Mushroom supervised learning lab we did recently, we mentioned we are concerned if our dataset has strongly correlated columns because if it is the case we need to choose certain ML algorithms instead of others. We need to evaluate this for our dataset now.
#
# Luckily, most of the columns in this dataset are ordinal which makes things a lot easier for us. In the next cells below, evaluate the level of collinearity of the data.
#
# We provide some general directions for you to consult in order to complete this step:
#
# 1. You will create a correlation matrix using the numeric columns in the dataset.
#
# 1. Create a heatmap using `seaborn` to visualize which columns have high collinearity.
#
# 1. Comment on which columns you might need to remove due to high collinearity.

# %%
# Your code here
websites.corr()
# Out:
#                                 URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  \
# URL                        1.000000   -0.014239                  -0.017486
# URL_LENGTH                -0.014239    1.000000                   0.928105
# NUMBER_SPECIAL_CHARACTERS -0.017486    0.928105                   1.000000
# CHARSET                   -0.013110    0.070359                   0.085029
# SERVER                     0.002342   -0.028471                  -0.021401
# WHOIS_COUNTRY             -0.023471    0.030695                   0.035801
# WHOIS_STATEPRO             0.002764    0.041601                   0.028743
# WHOIS_REGDATE              0.027779   -0.102858                  -0.084786
# WHOIS_UPDATED_DATE         0.013997   -0.036840                   0.000591
# TCP_CONVERSATION_EXCHANGE  0.280663    0.036241                   0.028267
# DIST_REMOTE_TCP_PORT       0.157054    0.027622                   0.015806
# ...

# %%
encol
# Out:
# ['URL',
#  'CHARSET',
#  'SERVER',
#  'WHOIS_COUNTRY',
#  'WHOIS_STATEPRO',
#  'WHOIS_REGDATE',
#  'WHOIS_UPDATED_DATE']

# %%
import seaborn as sns
sns.heatmap(websites.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Challenge 2 - Remove Column Collinearity.
#
# From the heatmap you created, you should have seen at least 3 columns that can be removed due to high collinearity. Remove these columns from the dataset.
#
# Note that you should remove as few columns as you can. You don't have to remove all the columns at once. But instead, try removing one column, then produce the heatmap again to determine if additional columns should be removed. As long as the dataset no longer contains columns that are correlated for over 90%, you can stop. Also, keep in mind when two columns have high collinearity, you only need to remove one of them but not both.
#
# In the cells below, remove as few columns as you can to eliminate the high collinearity in the dataset. Make sure to comment on your way so that the instructional team can learn about your thinking process which allows them to give feedback. At the end, print the heatmap again.

# %%
# Your comment here
# URL length - number of special characters
# source app packets - tcp conversation exchange
# app packets - tcp conversation exchange
# remote app bytes - app bytes
# app packets - source app packets
del websites['NUMBER_SPECIAL_CHARACTERS']
del websites['APP_PACKETS']
del websites['TCP_CONVERSATION_EXCHANGE']
del websites['APP_BYTES']

# %%
# Your code here
websites
# Out:
#        URL  URL_LENGTH  CHARSET  SERVER  WHOIS_COUNTRY  WHOIS_STATEPRO  \
# 1      715          16        4      51             27              80
# 2     1165          16        3     107             27              80
# 3      121          17        1     145             37               3
# 5      489          18        4     145             30              53
# 6      870          18        1      10             37              21
# ...    ...         ...      ...     ...            ...             ...
# 1762   619         146        4     145             37               9
# 1763   336         149        1     174              7             104
# 1766  1030         154        4     174             37             120
# 1769   646         161        1      58             27              80
# 1770   518         169        4      90              5              75
#
#       WHOIS_REGDATE  WHOIS_UPDATED_DATE  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# ...

# %%
# Your comment here

# %%
# Print heatmap again
sns.heatmap(websites.corr())
# Out:
# <AxesSubplot:>

# %%
del websites['REMOTE_APP_BYTES']

# %%
sns.heatmap(websites.corr())
# Out:
# <AxesSubplot:>

# %%
del websites['REMOTE_APP_PACKETS']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
heatmap = sns.heatmap(websites.corr(), vmin=-1, vmax=1, annot=True)

# %% [markdown]
# # Challenge 3 - Handle Missing Values
#
# The next step would be handling missing values. **We start by examining the number of missing values in each column, which you will do in the next cell.**

# %% [markdown]
# If you remember in the previous labs, we drop a column if the column contains a high proportion of missing values. After dropping those problematic columns, we drop the rows with missing values.
#
# #### In the cells below, handle the missing values from the dataset. Remember to comment the rationale of your decisions.

# %% [markdown]
# dealt with missing values in previous steps, didnt want to encode beofre because otherwise missing values would have been encoded as its own label, and detected fairly quickly the large amount of missing data for content length and the possibility to drop it because it does not strongly relate to the result

# %%
# Your code here

# %%
# Your comment here

# %% [markdown]
# #### Again, examine the number of missing values in each column.
#
# If all cleaned, proceed. Otherwise, go back and do more cleaning.

# %%
# Examine missing values in each column
websites.isnull().sum()
# Out:
# URL                     0
# URL_LENGTH              0
# CHARSET                 0
# SERVER                  0
# WHOIS_COUNTRY           0
# WHOIS_STATEPRO          0
# WHOIS_REGDATE           0
# WHOIS_UPDATED_DATE      0
# DIST_REMOTE_TCP_PORT    0
# REMOTE_IPS              0
# SOURCE_APP_PACKETS      0
# SOURCE_APP_BYTES        0
# DNS_QUERY_TIMES         0
# Type                    0
# dtype: int64

# %% [markdown]
# # Challenge 4 - Handle `WHOIS_*` Categorical Data

# %% [markdown]
# There are several categorical columns we need to handle. These columns are:
#
# * `URL`
# * `CHARSET`
# * `SERVER`
# * `WHOIS_COUNTRY`
# * `WHOIS_STATEPRO`
# * `WHOIS_REGDATE`
# * `WHOIS_UPDATED_DATE`
#
# How to handle string columns is always case by case. Let's start by working on `WHOIS_COUNTRY`. Your steps are:
#
# 1. List out the unique values of `WHOIS_COUNTRY`.
# 1. Consolidate the country values with consistent country codes. For example, the following values refer to the same country and should use consistent country code:
#     * `CY` and `Cyprus`
#     * `US` and `us`
#     * `SE` and `se`
#     * `GB`, `United Kingdom`, and `[u'GB'; u'UK']`
#
# #### In the cells below, fix the country values as intructed above.

# %%
dic = {'cyprus':'cy','gb':'uk','united kingdom':'uk',"[u'gb'; u'uk']":'uk'}

# %%
websites.replace(dic, inplace=True)

# %%
# Your code here
for x in encol:
    print(websites[x].unique())
# Out:
# ['b0_2314' 'b0_911' 'b0_113' ... 'b0_755' 'b0_2237' 'b0_2099']
# ['utf-8' 'us-ascii' 'iso-8859-1' 'none' 'iso-8859' 'windows-1252']
# ['apache/2.4.10' 'microsoft-httpapi/2.0' 'nginx' 'apache/2' 'apache'
#  'none' 'apache/2.2.15 (red hat)' 'apache/2.2.22' 'apache/2.4.7 (ubuntu)'
#  'nginx/1.12.0'
#  'apache/2.4.12 (unix) openssl/1.0.1e-fips mod_bwlimited/1.4'
#  'oracle-iplanet-web-server/7.0' 'cloudflare-nginx' 'heptu web server'
#  'pepyaka/1.11.3' 'nginx/1.8.0' 'nginx/1.10.1 + phusion passenger 5.0.30'
#  'apache/2.2.29 (amazon)' 'microsoft-iis/7.5' 'litespeed'
#  'apache/2.4.25 (cpanel) openssl/1.0.1e-fips mod_bwlimited/1.4'
#  'apache/2.2.0 (fedora)' 'openresty/1.11.2.1' 'apache/2.4.25'
#  'apache/2.4.25 (amazon) php/7.0.14'
#  'apache/2.4.23 (unix) openssl/0.9.8e-fips-rhel5 mod_bwlimited/1.4'
#  'tsa_c' 'apache/2.4.25 (amazon) openssl/1.0.1k-fips'
#  'apache/2.2.22 (debian)' 'apache/2.2.22 (ubuntu)' 'tengine'
#  'apache/2.4.18 (unix) openssl/0.9.8e-fips-rhel5 mod_bwlimited/1.4'
# ...

# %%
encol
# Out:
# ['URL',
#  'CHARSET',
#  'SERVER',
#  'WHOIS_COUNTRY',
#  'WHOIS_STATEPRO',
#  'WHOIS_REGDATE',
#  'WHOIS_UPDATED_DATE']

# %%
del websites['WHOIS_UPDATED_DATE']

# %%
del websites['WHOIS_STATEPRO']

# %%
websites.drop(websites[websites['WHOIS_REGDATE'].str.startswith('0')].index, inplace=True)

# %%
encol.remove('WHOIS_STATEPRO')
encol.remove('WHOIS_UPDATED_DATE')

# %%
for x in encol:
    print(websites[x].unique())
# Out:
# ['m0_109' 'b0_2314' 'b0_911' ... 'b0_755' 'b0_2237' 'b0_2099']
# ['iso-8859-1' 'utf-8' 'us-ascii' 'none' 'windows-1251' 'iso-8859'
#  'windows-1252']
# ['nginx' 'apache/2.4.10' 'microsoft-httpapi/2.0' 'apache/2' 'nginx/1.10.1'
#  'apache' 'none' 'apache/2.2.15 (red hat)'
#  'apache/2.4.23 (unix) openssl/1.0.1e-fips mod_bwlimited/1.4'
#  'apache/2.2.22' 'apache/2.4.7 (ubuntu)' 'nginx/1.12.0'
#  'apache/2.4.12 (unix) openssl/1.0.1e-fips mod_bwlimited/1.4'
#  'oracle-iplanet-web-server/7.0' 'cloudflare-nginx' 'nginx/1.6.2'
#  'heptu web server' 'pepyaka/1.11.3' 'nginx/1.8.0'
#  'nginx/1.10.1 + phusion passenger 5.0.30' 'apache/2.2.29 (amazon)'
#  'microsoft-iis/7.5' 'litespeed'
#  'apache/2.4.25 (cpanel) openssl/1.0.1e-fips mod_bwlimited/1.4'
#  'apache/2.2.0 (fedora)' 'openresty/1.11.2.1' 'apache/2.4.25'
#  'apache/2.2.15 (centos)'
#  'apache/2.4.23 (unix) openssl/0.9.8e-fips-rhel5 mod_bwlimited/1.4'
#  'tsa_c' 'apache/2.4.25 (amazon) openssl/1.0.1k-fips'
# ...

# %%
websites
# Out:
#           URL  URL_LENGTH     CHARSET                  SERVER WHOIS_COUNTRY  \
# 1     b0_2314          16       utf-8           apache/2.4.10         other
# 2      b0_911          16    us-ascii   microsoft-httpapi/2.0         other
# 3      b0_113          17  iso-8859-1                   nginx         other
# 6      b0_462          18  iso-8859-1                apache/2         other
# 7     b0_1128          19    us-ascii   microsoft-httpapi/2.0         other
# ...       ...         ...         ...                     ...           ...
# 1762   b0_221         146       utf-8                   nginx         other
# 1763  b0_1361         149  iso-8859-1                    none         other
# 1766   b0_755         154       utf-8                    none         other
# 1769  b0_2237         161  iso-8859-1  apache/2.4.18 (ubuntu)         other
# 1770  b0_2099         169       utf-8        cloudflare-nginx         other
#
# ...

# %% [markdown]
# Since we have fixed the country values, can we convert this column to ordinal now?
#
# Not yet. If you reflect on the previous labs how we handle categorical columns, you probably remember we ended up dropping a lot of those columns because there are too many unique values. Too many unique values in a column is not desirable in machine learning because it makes prediction inaccurate. But there are workarounds under certain conditions. One of the fixable conditions is:
#
# #### If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.
#
# The `WHOIS_COUNTRY` column happens to be this case. You can verify it by print a bar chart of the `value_counts` in the next cell to verify:

# %%
# Your code here
top10 = list(websites['WHOIS_COUNTRY'].value_counts().index[:10])
other = [x for x in list(websites['WHOIS_COUNTRY']) if x not in top10]

# %%
for x in other:
    websites.loc[websites['WHOIS_COUNTRY'] == x, 'WHOIS_COUNTRY'] = 'other'

# %% [markdown]
# #### After verifying, now let's keep the top 10 values of the column and re-label other columns with `OTHER`.

# %%
# Your code here
websites['WHOIS_COUNTRY'].value_counts()
# Out:
# us       842
# none     264
# other     81
# ca        68
# es        47
# uk        31
# au        29
# pa        19
# cn        10
# in         8
# jp         8
# Name: WHOIS_COUNTRY, dtype: int64

# %% [markdown]
# Now since `WHOIS_COUNTRY` has been re-labelled, we don't need `WHOIS_STATEPRO` any more because the values of the states or provinces may not be relevant any more. We'll drop this column.
#
# In addition, we will also drop `WHOIS_REGDATE` and `WHOIS_UPDATED_DATE`. These are the registration and update dates of the website domains. Not of our concerns.
#
# #### In the next cell, drop `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
# Your code here

# %% [markdown]
# # Challenge 5 - Handle Remaining Categorical Data & Convert to Ordinal
#
# Now print the `dtypes` of the data again. Besides `WHOIS_COUNTRY` which we already fixed, there should be 3 categorical columns left: `URL`, `CHARSET`, and `SERVER`.

# %%
# Your code here

# %% [markdown]
# #### `URL` is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.

# %%
# Your code here
del websites['URL']

# %% [markdown]
# #### Print the unique value counts of `CHARSET`. You see there are only a few unique values. So we can keep it as it is.

# %%
# Your code here
websites['CHARSET'].unique()
# Out:
# array(['iso-8859-1', 'utf-8', 'us-ascii', 'none', 'windows-1251',
#        'iso-8859', 'windows-1252'], dtype=object)

# %% [markdown]
# `SERVER` is a little more complicated. Print its unique values and think about how you can consolidate those values.
#
# #### Before you think of your own solution, don't read the instructions that come next.

# %%
# Your code here
servers = list(websites['SERVER'].value_counts().index[:10])

# %%
servers
# Out:
# ['apache',
#  'nginx',
#  'none',
#  'microsoft-httpapi/2.0',
#  'cloudflare-nginx',
#  'microsoft-iis/7.5',
#  'nginx/1.12.0',
#  'server',
#  'youtubefrontend',
#  'gse']

# %%
websites['SERVER'].value_counts().index[:10]
# Out:
# Index(['apache', 'nginx', 'none', 'microsoft-httpapi/2.0', 'cloudflare-nginx',
#        'microsoft-iis/7.5', 'nginx/1.12.0', 'server', 'youtubefrontend',
#        'gse'],
#       dtype='object')

# %%
allsev = list(websites['SERVER'])
len(allsev)
len(othersev)
# Out:
# 139

# %%
servers
# Out:
# ['apache',
#  'nginx',
#  'none',
#  'microsoft-httpapi/2.0',
#  'cloudflare-nginx',
#  'microsoft-iis/7.5',
#  'nginx/1.12.0',
#  'server',
#  'youtubefrontend',
#  'gse']

# %%
othersev = [x for x in allsev if x not in servers]

# %%
for x in servers:
    websites.loc[websites['SERVER'].str.contains(x), 'SERVER'] = x

# %%
websites['SERVER'].unique()
# Out:
# array(['nginx', 'apache', 'microsoft-httpapi/2.0', 'none', 'server',
#        'pepyaka/1.11.3', 'microsoft-iis/7.5', 'litespeed',
#        'openresty/1.11.2.1', 'tsa_c', 'tengine', 'amazons3', 'ats',
#        'cherrypy/3.6.0', 'mw2114.codfw.wmnet', 'httpdaemon', 'mediafire',
#        'dosarrest', 'mw2232.codfw.wmnet', 'sucuri/cloudproxy',
#        'mw2260.codfw.wmnet', 'dps/1.1.8', 'gse', 'ats/5.3.0', 'openresty',
#        'microsoft-iis/8.0', 'youtubefrontend', 'squeegit/1.2.5 (3_sir)',
#        'virtuoso/07.20.3217 (linux) i686-generic-linux-glibc212-64  vdb',
#        'mw2239.codfw.wmnet', 'yippee-ki-yay', 'mw2165.codfw.wmnet',
#        'mw2192.codfw.wmnet', 'mw2231.codfw.wmnet', 'openresty/1.11.2.2',
#        'mw2225.codfw.wmnet', 'mw2236.codfw.wmnet', 'mw2101.codfw.wmnet',
#        'resin/3.1.8', 'mw2164.codfw.wmnet', 'microsoft-iis/8.5',
#        'mw2242.codfw.wmnet', 'mw2175.codfw.wmnet', 'barista/5.1.3',
# ...

# %%
for x in othersev:
        websites.loc[websites['SERVER'] == x, 'SERVER'] = 'other'

# %%
websites['SERVER'].unique()
# Out:
# array(['nginx', 'apache', 'microsoft', 'none', 'server', 'other', 'gse',
#        'youtube'], dtype=object)

# %%
websites.loc[websites['SERVER'].str.contains('microsoft'), 'SERVER'] = 'microsoft'

# %%
# for x in event_list:
#     austin_fix[x] = np.where(austin_fix['Events'].str.contains(x),1,0)

# %% [markdown]
# Although there are so many unique values in the `SERVER` column, there are actually only 3 main server types: `Microsoft`, `Apache`, and `nginx`. Just check if each `SERVER` value contains any of those server types and re-label them. For `SERVER` values that don't contain any of those substrings, label with `Other`.
#
# At the end, your `SERVER` column should only contain 4 unique values: `Microsoft`, `Apache`, `nginx`, and `Other`.

# %%
# Your code here
websites['WHOIS_REGDATE'].unique()
websites.drop(websites[websites['WHOIS_REGDATE']=='3-20'].index, inplace=True)

# %%
websites['WHOIS_REGDATE'].unique()
# Out:
# array(['2015', 'No date', '1997', '2002', '2014', '2007', '2016', '2000',
#        '2013', '1999', '2003', '2008', '2009', '2005', '2001', '2006',
#        '1996', '1995', '1998', '2011', '2004', '2010', '1994', '2017',
#        '2012', '1993', '1992', '1990'], dtype=object)

# %%
encol.remove('URL')

# %%
# Count `SERVER` value counts here
websites['WHOIS_REGDATE'].value_counts()
# Out:
# 2000       123
# No date    111
# 1995        97
# 2008        89
# 1999        86
# 2005        85
# 2003        79
# 2001        79
# 1996        78
# 2006        68
# 2002        66
# 1997        66
# 2004        63
# 1994        59
# 1998        59
# 2007        53
# 2009        36
# 2010        29
# 2016        22
# 2015        11
# 2011        10
# 2014         9
# 2013         7
# 1993         5
# 2017         4
# 1990         4
# 1992         3
# 2012         1
# Name: WHOIS_REGDATE, dtype: int64

# %% [markdown]
# OK, all our categorical data are fixed now. **Let's convert them to ordinal data using Pandas' `get_dummies` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)).** Make sure you drop the categorical columns by passing `drop_first=True` to `get_dummies` as we don't need them any more. **Also, assign the data with dummy values to a new variable `website_dummy`.**

# %%
from sklearn import preprocessing

encoded1 = websites
le = preprocessing.LabelEncoder()
for x in encol:   
    le.fit(encoded1[x])
    le.transform(encoded1[x])
    encoded1[x] = le.transform(encoded1[x])
    
encoded2 = websites

encoded2 = pd.get_dummies(encoded2, drop_first=True)

# %%
# Your code here
encoded1
# Out:
#       URL_LENGTH  CHARSET  SERVER  WHOIS_COUNTRY  WHOIS_REGDATE  \
# 0             16        1       3              6             24
# 1             16        4       0              6             27
# 2             16        3       2              6             27
# 3             17        1       3             10              6
# 6             18        1       0             10             11
# ...          ...      ...     ...            ...            ...
# 1763         149        1       4              1              6
# 1764         150        4       0              3             17
# 1766         154        4       4             10              7
# 1769         161        1       0              6             19
# 1770         169        4       3              7             17
#
#       DIST_REMOTE_TCP_PORT  REMOTE_IPS  SOURCE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0                        0           2                   9              1153
# ...

# %% [markdown]
# Now, inspect `website_dummy` to make sure the data and types are intended - there shouldn't be any categorical columns at this point.

# %%
# Your code here
encoded2
# Out:
#       URL_LENGTH  CHARSET  SERVER  WHOIS_COUNTRY  WHOIS_REGDATE  \
# 0             16        1       3              6             24
# 1             16        4       0              6             27
# 2             16        3       2              6             27
# 3             17        1       3             10              6
# 6             18        1       0             10             11
# ...          ...      ...     ...            ...            ...
# 1763         149        1       4              1              6
# 1764         150        4       0              3             17
# 1766         154        4       4             10              7
# 1769         161        1       0              6             19
# 1770         169        4       3              7             17
#
#       DIST_REMOTE_TCP_PORT  REMOTE_IPS  SOURCE_APP_PACKETS  SOURCE_APP_BYTES  \
# 0                        0           2                   9              1153
# ...

# %%
encoded2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1402 entries, 0 to 1770
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   URL_LENGTH            1402 non-null   int64
#  1   CHARSET               1402 non-null   int32
#  2   SERVER                1402 non-null   int32
#  3   WHOIS_COUNTRY         1402 non-null   int32
#  4   WHOIS_REGDATE         1402 non-null   int32
#  5   DIST_REMOTE_TCP_PORT  1402 non-null   int64
#  6   REMOTE_IPS            1402 non-null   int64
#  7   SOURCE_APP_PACKETS    1402 non-null   int64
#  8   SOURCE_APP_BYTES      1402 non-null   int64
#  9   DNS_QUERY_TIMES       1402 non-null   float64
#  10  Type                  1402 non-null   int64
# dtypes: float64(1), int32(4), int64(6)
# memory usage: 109.5 KB

# %% [markdown]
# # Challenge 6 - Modeling, Prediction, and Evaluation
#
# We'll start off this section by splitting the data to train and test. **Name your 4 variables `X_train`, `X_test`, `y_train`, and `y_test`. Select 80% of the data for training and 20% for testing.**

# %%
from sklearn.model_selection import train_test_split

# Your code here:
x = encoded2.drop('Type', axis=1)
y = encoded2['Type']
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#       URL_LENGTH  CHARSET  SERVER  WHOIS_COUNTRY  WHOIS_REGDATE  \
# 593           42        4       3             10             15
# 54            24        4       3              6              4
# 188           31        4       0             10             15
# 1010          54        1       0              6             27
# 1340          68        4       6             10              3
# ...          ...      ...     ...            ...            ...
# 1366          70        1       0             10              0
# 1414          72        4       3              8             16
# 1623          99        1       2              7             25
# 1083          56        3       2             10             12
# 1409          72        1       0              7              9
#
#       DIST_REMOTE_TCP_PORT  REMOTE_IPS  SOURCE_APP_PACKETS  SOURCE_APP_BYTES  \
# 593                      0           0                   0                 0
# ...

# %%
y_test.value_counts()
# Out:
# 0    256
# 1     25
# Name: Type, dtype: int64

# %% [markdown]
# #### In this lab, we will try two different models and compare our results.
#
# The first model we will use in this lab is logistic regression. We have previously learned about logistic regression as a classification algorithm. In the cell below, load `LogisticRegression` from scikit-learn and initialize the model.

# %%
# Your code here:
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# Next, fit the model to our training data. We have already separated our data into 4 parts. Use those in your model.

# %%
# Your code here:
model =  LogisticRegression()
result = model.fit(x_train, y_train)
predictions = result.predict(x_test)
# Out:
# C:\Users\leube\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# finally, import `confusion_matrix` and `accuracy_score` from `sklearn.metrics` and fit our testing data. Assign the fitted data to `y_pred` and print the confusion matrix as well as the accuracy score

# %%
# Your code here:

print('The accuracy of the Decision Tree is', '{:.3f}'.format(metrics.accuracy_score(predictions,y_test)))

# matrix
cn = ['not risk', 'risk']
cm = metrics.plot_confusion_matrix(model, x_test, y_test,
                                 display_labels=cn,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
cm.ax_.set_title('Decision Tree Confusion matrix, without normalization');
# Out:
# The accuracy of the Decision Tree is 0.890

# %% [markdown]
# What are your thoughts on the performance of the model? Write your conclusions below.

# %%
# Your conclusions here:
# Out:
# array([0], dtype=int64)

# %% [markdown]
# #### Our second algorithm is is K-Nearest Neighbors.
#
# Though is it not required, we will fit a model using the training data and then test the performance of the model using the testing data. Start by loading `KNeighborsClassifier` from scikit-learn and then initializing and fitting the model. We'll start off with a model where k=3.

# %%
from sklearn.neighbors import KNeighborsClassifier
# Your code here:
# k_range = list(range(1,40))
# scores = []
# for k in k_range:
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
   # scores.append(metrics.accuracy_score(y_test, y_pred))
   # print ('-------------', k, '-------------------')
    #print (metrics.accuracy_score(y_test, y_pred))
   # print(metrics.confusion_matrix(y_test, y_pred))
# plt.plot(k_range, scores)
# plt.xlabel('Value of k for KNN')
# plt.ylabel('Accuracy Score')
# plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
# plt.show()

# %% [markdown]
# To test your model, compute the predicted values for the testing sample and print the confusion matrix as well as the accuracy score.

# %%
# Your code here:
print('The accuracy of the KNN Tree is', '{:.3f}'.format(metrics.accuracy_score(y_pred,y_test)))

# matrix
cn = ['not risk', 'risk']
cm = metrics.plot_confusion_matrix(knn, x_test, y_test,display_labels=cn,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
cm.ax_.set_title('Decision Tree Confusion matrix, without normalization');
# Out:
# The accuracy of the KNN Tree is 0.932

# %% [markdown]
# #### We'll create another K-Nearest Neighbors model with k=5.
#
# Initialize and fit the model below and print the confusion matrix and the accuracy score.

# %%
# Your code here:

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

# %% [markdown]
# Did you see an improvement in the confusion matrix when increasing k to 5? Did you see an improvement in the accuracy score? Write your conclusions below.

# %%
# Your conclusions here:
print('The accuracy of the KNN Tree is', '{:.3f}'.format(metrics.accuracy_score(y_pred,y_test)))

# matrix
cm = metrics.plot_confusion_matrix(knn, x_test, y_test,
                                 cmap=plt.cm.Blues,display_labels=cn,
                                 normalize=None)
cm.ax_.set_title('KNN Confusion matrix, without normalization');
# Out:
# The accuracy of the KNN Tree is 0.932

# %% [markdown]
# #### Please implement decision tree, random forest, SVM and extra tree. Which model is better?

# %%
from sklearn.ensemble import RandomForestClassifier
m=RandomForestClassifier()
result = m.fit(x_train,y_train)
prediction = result.predict(x_test)

# %%
print('The accuracy of the Forest Tree is', '{:.3f}'.format(metrics.accuracy_score(prediction,y_test)))

# matrix
cm = metrics.plot_confusion_matrix(knn, x_test, y_test,display_labels=cn,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
cm.ax_.set_title('Forest Confusion matrix, without normalization');
# Out:
# The accuracy of the Forest Tree is 0.954

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
tree = DecisionTreeClassifier(max_depth=5, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=1, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0, criterion='entropy')
tree.fit(x_train,y_train)
prediction = tree.predict(x_test)

# %%
print('The accuracy of the Tree is', '{:.3f}'.format(metrics.accuracy_score(prediction,y_test)))

# matrix
cm = metrics.plot_confusion_matrix(knn, x_test, y_test,display_labels=cn,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
cm.ax_.set_title('Tree Confusion matrix, without normalization');
# Out:
# The accuracy of the Tree is 0.954

# %% [markdown]
# # Bonus Challenge - Feature Scaling
#
# Problem-solving in machine learning is iterative. You can improve your model prediction with various techniques (there is a sweetspot for the time you spend and the improvement you receive though). Now you've completed only one iteration of ML analysis. There are more iterations you can conduct to make improvements. In order to be able to do that, you will need deeper knowledge in statistics and master more data analysis techniques. In this bootcamp, we don't have time to achieve that advanced goal. But you will make constant efforts after the bootcamp to eventually get there.
#
# However, now we do want you to learn one of the advanced techniques which is called *feature scaling*. The idea of feature scaling is to standardize/normalize the range of independent variables or features of the data. This can make the outliers more apparent so that you can remove them. This step needs to happen during Challenge 6 after you split the training and test data because you don't want to split the data again which makes it impossible to compare your results with and without feature scaling. For general concepts about feature scaling, click [here](https://en.wikipedia.org/wiki/Feature_scaling). To read deeper, click [here](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# In the next cell, attempt to improve your model prediction accuracy by means of feature scaling. A library you can utilize is `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). You'll use the `RobustScaler` to fit and transform your `X_train`, then transform `X_test`. You will use logistic regression to fit and predict your transformed data and obtain the accuracy score in the same way. Compare the accuracy score with your normalized data with the previous accuracy data. Is there an improvement?

# %%
# Your code here
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler().fit(x_train)
x_train = transformer.transform(x_train)

transformer = RobustScaler().fit(x_test)
x_test = transformer.transform(x_test)

# %%
model =  LogisticRegression()
result = model.fit(x_train, y_train)
predictions = result.predict(x_test)
print('The accuracy of the Decision Tree is', '{:.3f}'.format(metrics.accuracy_score(predictions,y_test)))

# matrix
cn = ['not risk', 'risk']
cm = metrics.plot_confusion_matrix(model, x_test, y_test,
                                 display_labels=cn,
                                 cmap=plt.cm.Blues,
                                 normalize=None)
cm.ax_.set_title('Decision Tree Confusion matrix, without normalization');

# score has increased by 4 percent, I see a bigger problem than general accuracy, of course we want to detect as many risk
# cases as possile, the model thoguh manages to predict only ruffly 50% of these cases
# Out:
# The accuracy of the Decision Tree is 0.925
