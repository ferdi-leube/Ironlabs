# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located in the lab directory named `Sentiment140.csv.zip`. You need to unzip it into a `.csv` file. Then in the cell below, load and explore the data.
#
# *Notes:*
#
# * The dataset was downloaded from [Kaggle](https://www.kaggle.com/kazanova/sentiment140). We made a slight change on the original data so that each column has a label.
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here
import pandas as pd
import numpy as np

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
nltk.download('stopwords')
import re
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\leube\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv(r"C:\Users\leube\Downloads\Sentiment140.csv")

# %%
data = pd.read_csv(r"C:\Users\leube\Downloads\Sentiment140.csv")
data = data.sample(frac=0.4, random_state=42)

# %%
data['text']
# Out:
# 541200                @chrishasboobs AHHH I HOPE YOUR OK!!!
# 750        @misstoriblack cool , i have no tweet apps  fo...
# 766711     @TiannaChaos i know  just family drama. its la...
# 285055     School email won't open  and I have geography ...
# 705995                                upper airways problem
#                                  ...
# 915057     my sidekick is awkward flashing. oh well. leav...
# 1501831    Played Sims 3 for almost 6 hours!  Now time fo...
# 108371     Eugh! Reception sucks, they pass everything on...
# 552550     Activity made on: DM and Fav buttons disapeare...
# 403494            I wish i had another phone charger so bad
# Name: text, Length: 640000, dtype: object

# %%
def clean_up_tokenize(text):
    """
    Cleans up numbers, URLs, and special characters from a string.

    Args:
        s: The string to be cleaned up.

    Returns:
        A string that has been cleaned up.
    
    
    """

    new = text.split(sep=' ')
    nolink = [x for x in new if x.startswith('http') == False]
    text = " ".join(nolink)
    text = re.sub(r"[^a-zA-Z]", " ", text)
    text = text.lower()
    return text.split()

# %%
def stem_and_lemmatize(words):
    """
    Perform stemming and lemmatization on a list of words.

    Args:
        l: A list of strings.

    Returns:
        A list of strings after being stemmed and lemmatized.
    """
    # Reduce words to their stems
    stemmed = [PorterStemmer().stem(w) for w in words]
    # Reduce words to their root form
    lemmed = [WordNetLemmatizer().lemmatize(w) for w in stemmed]
    return lemmed

# %%
def remove_stopwords(words):
    """
    Remove English stopwords from a list of strings.

    Args:
        l: A list of strings.

    Returns:
        A list of strings after stop words are removed.
    """
    words = [w for w in words if w not in stopwords.words("english")]
    # words = [w for w in words if len(w)>1]
    return words

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
# your code here
list(data['text'])
# Out:
# ['@chrishasboobs AHHH I HOPE YOUR OK!!! ',
#  '@misstoriblack cool , i have no tweet apps  for my razr 2',
#  '@TiannaChaos i know  just family drama. its lame.hey next time u hang out with kim n u guys like have a sleepover or whatever, ill call u',
#  "School email won't open  and I have geography stuff on there to revise! *Stupid School* :'(",
#  'upper airways problem ',
#  "Going to miss Pastor's sermon on Faith... ",
#  'on lunch....dj should come eat with me ',
#  '@piginthepoke oh why are you feeling like that? ',
#  'gahh noo!peyton needs to live!this is horrible ',
#  '@mrstessyman thank you glad you like it! There is a product review bit on the site  Enjoy knitting it!',
#  "@PerezHilton Zach makes me pee sitting down! And I'm a grown gay man! ",
#  'to sum up my day in one word ......... kackered! ',
#  '@k9wkj Great minds think alike ',
#  'Is Poorly and in bed! ',
#  "@LilPecan Oh, that's really great  Here we have a small blizzard and also cold wind blows...",
#  '@wizely lol, calm down.  i got a 30day loan offer for only 1500% ',
#  "i'm feeling quite sleepy today, wish i could stay in bed today...but OK! is my LAST YEAR, so let's go to school ",
#  '@nadalnews Yeah  Mathieu totally choked in the 3rd set to let Rog win as well. Djokovic played TERRIBLY.  ',
#  "ugh, morning's off to a rough start ",
#  'just bit my tongue ',
#  '@frandrescher Apparently you dont have time for ur fans!!!!!!!!!! ',
#  'Whaddup Whaddup Whaddup Whaddup Whaddup  I Got white girl swag from MY HEAD TO MY shOES Whaddup @yungla ',
#  "@GogDog I'd be willing to pay $40-50 (thus covering the cost of the set) for one of them, but if you've got a counter offer I'll listen. ",
#  "Working on photos from Hillsong's 1 year celebration!!! stay tuned   www.hillsong.co.za",
#  "baby's chicken pox are soo bad on the face, I am afraid she might have scars ",
#  "i don't feel good ",
#  '@edadkins ha ha I want to see pictures from when you were a minister!!!  *boobie flahses*!!!! ',
#  'This day will pass slowly.  All of these days will.  RAWR!!!!  ... ',
#  'my car is poorly ',
#  "im turning 18 one week from now  but i don't feel excited  i really don't know why i've seen my friends  they got excited  but on my part",
#  'No woooooork tomorrrow&amp;tuesday ',
#  'Flatmates are still in the bathroom! ARGGH!! ',
#  "I'm having an allergic reaction to silver earings ",
#  "@RocDoogie I am, I'll admit...  maybe I'll feel better tomorrow, yo! Down 4 studio time??",
#  "@jasonhooha Going back to sleep is such a great idea, unfortunately I'm already at work notebook-less ",
#  'what is with msn making me click the wrong people. garrrrr ',
#  'Too full of fizz but not enough cider ',
#  'How to Get Your Ex Back (worked for me  http://bit.ly/ec8qJ',
#  'Time to sleep... Long day again tomorrow ',
#  'Hahaha blakk is reckkkin it. :p throwwwwwed. ',
#  'Cubs game today! My first ever ',
#  "@SuzySpaatz ~ hi! sounds like you're feeling a bit better...that's great! you have a great day! ",
#  '@foprof LOL.  Leave a kid on internet and the kid will do stupid things.',
#  'eating cha with eric ',
#  "@StarJonesEsq On a good note, we DID meet at Marty Richards RED BALL a few years ago, you were so sweet to me I'll never forget it ",
#  "My hands are officially tied. I don't think I'll have time for anything anymore  This includes the California meet ",
#  '@Konstantine I said &quot;scar,&quot; sweetie. ',
#  "@CamilleJ it was supposed to go live on tv but it didn't happened in the end  that would have been cool being on the bbc...",
#  'FCK-Br�ndby 4-0! ',
#  "@team_allen jealous!  I'm yet to find a local chinese i'm satisfied with ",
#  '@BayAreaCheap there r a few of us local yocals around  happy to find u on twitter 2day',
#  'just back from SuperCheap - a most successful trip. The bikes are tanked &amp; checked for the week, so all ready to start relaxing ',
#  "@ElleChanel want to shoot...but i'm not in charlotte .. ",
#  '@sephrenia1982 good work ',
#  '@KingdomGuard welcome new cd out this week...maybe even tomorrow! ',
#  '@CatholicChicks hate bein on the phone that long ',
#  "If anyone wanted to attend TEDMED but can't make the date, I'll happily take your place, and will live-blog it for you too ",
#  '@melbgirl It means the same to us!  #GoCats',
#  'beach this morning,bbq this afternoon. Back to school/work 2morro ',
#  '@joshlam and you are how old?? REALLY?!? ',
#  '@bing siteowner custom search box fail... &quot;market&quot;:&quot;en-AU&quot; does nothing - it still targets US search   should be &quot;only from australia&quot;??',
#  'Watched Crank 2.... awesome ',
#  '@TheUncoolest ',
#  'Night in with the rock star...  ',
#  "@BATYASMUSIC Don't really have a reason.. haha sounds stupid. I'll be 14 ",
#  "first night in myers. just not the same w/out lydia!  but i'm actually excited about this summer! ",
#  'my tooth is sving, and I cannot see my dentist for a week ',
#  'cant sleep got heartburn really bad ',
#  "Off to Whipsnade  Hope it's dry",
#  'Going To Bed ...My Ankle Hurts ',
#  'hates the fact she scanned the wrong passage in all those commentaries she was going to use for her essay ',
#  'I shame the name of female  lol Alright. Shower then sleep then get up in like 5 hours.',
#  "@disil429 Fine. Kinders coughing again, so not a lot of sleep. Weather's good, though, that's the main thing ",
#  "Listening to the Nutcracker.  Who says it's only a Christmas thing?! ",
#  'i miss him, i cant wait to see him, im happy ',
#  "@tristanwilds are you missing me? i'm missing my tuesday nights of 90210 ",
#  '@mithss mourniiiiiiing eh, morniiing!!! ',
#  '@pamelaong Glad the blog helped ',
#  'Awesome pumpkin! Your famous ',
#  "@ScarlettHarlott Sadly , I've never seen a single episode. I know , I'm fired , right? ",
#  '@LucasGo Haha. I will! o.O Hows you?  Long time no @ reply.',
#  "@PaulaAbdul awww, Good luck Paula!! Please don't work too hard  but I hope you have fun  Your new album is gonna be amazing!  xxx",
#  'Seattle PRIDE will be June 28th at 11am.  Come out and support your community! March with the marriage equality contingent! ',
#  "@Lujee seriosuly, the second one &quot;since I'm already a mid. class dude and would work for food&quot; ",
#  "at school...listining to die Ärzte - Westerland...great song really..btw i'm so tired...i sleeped between 02:30 and 05:30..thats bad ",
#  'I am so hungry  I hate not eating breakfast!',
#  "ewww if i work at fazoli's i have to year a viser...and ugly shoes...and a pony tail...and no nail polish ",
#  "@ZippyC NO. IT'S FULL OF WIN AND I LUV IT. &lt;3 I've been meaning to catch up to where it's at now for ages. NOW I HAVE. ",
#  "Oft. As finished as I can be. Can I relax and be on holiday now? I think I've missed the acceptable slot for lunch. ",
#  '@ItsNeet 100%.. its like getting an A for all your classes.. ',
#  "@seblefebvre Hi Seb! I'm a spanish fan of you.I'm addicted to SP and I think it's the best band in the world!please, come to spain early ",
#  "Home from soccer. It's so hot out there today. We have retreated to the coolness of the basement. ",
#  'i have find my someone ',
#  '@marqueshouston We are the &quot;Fugazi Patrol&quot; &amp; our motto is &quot;If u see a clown point em out&quot; please let everyone know about us ',
#  'it is ginormous... Haha well i  feel wierd talking about myy ziiiit  ta ta  good nightt',
#  "I'm obsessed with twitting  haha",
#  'One interlock down one to go ',
#  'ugh...summer colds are the worst, esp when you have a fever on top of this ridic humidity ',
#  'I miss Zack so much these days ',
#  "@dbferguson I'm using an Asus. Forget which one at the moment since I don't have it near me.But my complaints are similar to yours. ",
#  "@powersurf OH I've Got a case. I designed it. Someone idiot stole it and I can prove it. If they want to play hardball,I'm game. ",
#  'my thumb hurts after breaking the nail.... ',
#  "@amymacdonald1 Congrats on the 4x platinum  It's a fantastic album, one of my favs",
#  '@JosephFrost Yeahh, that would be pretty awesome. ',
#  '@benlizzotte so i think you should work for the discovery channel b/c then it would be media AND sharks! ',
#  '@paddyrules home is mums house lol hm maddens could be a plan, am actually stone cold broke atm tho not even sure i could afford door fee ',
#  "@MandyyJirouxx that page doesn't exist ",
#  'fighting a cold. ',
#  '@greeleyalex  aw im jealous! I miss home. I wish I could be home in CG right now! Watching spanish tv with my Gparents',
#  '@aleshacal my phone is dying  no charger here!',
#  '@mileycyrus Green Day new cd on the 15th and you on the 16th. woo!! ',
#  "my tv always freezes while i'm watching inbetweeners ",
#  '@softjunebreeze Ex-factor.... Me too ',
#  ' Back to school on Monday...Well I did get an iPod Touch. @shmuxel + @randomized180 See yah tomorrow then I guess ',
#  '@LisaAnneWest i missed it  have to catch up on sunday ohh ye so  fancy ldn on sunday? xoxo',
#  'tried to check out your site @poeticmindset ... not working ',
#  "Watching Wayne Dyer's new program on PBS &quot;Excuses Begone!&quot;. Lower mainlanders can check it out on ch. 27 or 204 on Shaw! Peace ",
#  'pimples attack! Arghhhhhhhhh ',
#  "has to pack, stillll. and doesn't want to.. ",
#  "@snikkins How dare you get some before I have a chance to. You're no longer my friend ",
#  "Can't stop listening to the clips of @Jonasbrothers new album Lines, Vines and Trying Times its so amazing can't wait for the whole thing ",
#  'about to pour in orlando ',
#  "@carriecruz I know! I don't think they air it on any of the cable channels anymore, but you can download them from the net ",
#  '@AprAnaya  you will !   check the website so you can have an idea as to what product u want to try . I will sent u the email tomorrow ',
#  '@annieomnious    can it be fixed?  can we make a new simple one mayb?',
#  'blää i have a headache ',
#  'Has just joined Twitter.. It better be good! ',
#  'Where in Singapore do they sell Dujour? ',
#  '#iranelection The &quot;yellow Press&quot; is alive and well in the 21st century, how quickly we forget the USS Maine ',
#  "haven't been on all day  went to bed late last night!",
#  "where's all the rain we were supposed to have today? not complaining tho, it's lovely &amp; bright. very happy making ",
#  '@claire_stokoe thank you, it only took me two minutes, thankfully the style of envirowise.gov.uk was already there for the taking ',
#  'ps: i think twitter sucks if you dont have free unlimited texts. ',
#  "@xDorkyStacy Ha! THAT SOUNDS SO WRONG STACY! lmao  i love you. and when I take one, I'll think of you too. haha, and on youtube. ",
#  '@gwyn007 @waz7710    no no really its ok! u try em out and then u can see which works and doesnt  by that time its to late',
#  'Who else misses Parade the day incredibly much.. ',
#  'I was caller number one. ',
#  '@StewartWade ditto!! Goodnight &amp; rest well!! Go play the lottery! I bought a ticket when I was n FL last week but no luck! ',
#  "Mornin every1! Hope all is well I'm your worlds. I'm not sure why I'm at work at 7:45 this mornin, but I guess Its not all bad ",
#  'should be going out but wants to stay put to participate in @RichardWiseman experiment - might have to do it by txt. (no photo part) ',
#  "If you can take criticism and blame without resentment, YOU'RE PROBABLY THE FAMILY DOG  see... http://jijr.com/hitZ cheers, Lou-ann",
#  "@TeeMonster Sorry, I know I'm late responding (15hrs  timezone troubles) but I think you would need to load Audacity to your compy",
#  'History exam today and dreading it ',
#  'After seeing mr. benningfield tonight it really made me start to miss my vand family like hXc  i love you band geeks! &lt;3',
#  'Just downloaded a new Twitter app for my phone. So much better already. ',
#  'I seem to be making a habbit out of not falling asleep until very late ',
#  "There was a steady stream at my polling station mostly old folks surely they wouldn't vote for the fascists ... Are people that stupid? ",
#  "Missionaries had passport problems. Still havn't arrived  ya'll pray!",
#  'had a very good night ',
#  "Enjoying the morning just hanging out with Juliet in Victoria. She doesn't know it yet, but I'm taking her to see Il Divo tonight  #fb",
#  'Off to the Miss Bikini Philippines pageant. Thanks to @veggiecircle for the ticket! ',
#  "i'm going global .. ",
#  'They are gone .. ',
#  'Friends with scott again ',
#  'I think that my lovely brother @ScottyHolloway should take me and his lovely sister @Ho11y to Old Town for some dinn dinn &amp; margaritas ',
#  'Roast in the cooker and cakes in the oven soon.  Good morning!  Hope everyone is well today ',
#  'Wooo I picked my sister and I miss the empty house. ',
#  '@aleahhh season is almost done with babe ',
#  'off to work    byeee xox',
#  '@alexandramusic Diversity won! damnn i wanted flawless to win ',
#  'printin stuff for my aunt. dont ask y its so late. i forgot 2 do it earlier. ',
#  ' can some one pleease tell me how to work out the total surface area of a square pyramid? ',
#  '@DENISE_RICHARDS love your hair  dont ever cut ur locks ',
#  "@okse *Phew* Hate to think you and Colin had fallen out! Glad he's smiling for you. Hip Hip Hip Hooray!! ",
#  '@Dee_Dee_3 high low ',
#  'And the motivation came!  yay! Not finished yet, but well on my way!  Gonna go finish it. xx',
#  'Still cant get Jonas Bros tickets..dreading facing my niece later on ( I can see the tantrum now). Hope they put on another gig in Dublin ',
#  'I though the clothes of AW0910 Collection from +9 designers will be there, together with the visual arts, but it is not ',
#  'On schedule now to soft launch tomorrow evening - already have first customer - lost cat ',
#  '&quot;Thank You [Lord] for reminding me to see myself the way You see me!&quot; ',
#  '@CharlieeSimpson I Was Looking at an Old Poster From Busted The Other Day  You Had Really Short Hair And Everythng   Young Ta Old ',
#  'Ugh, so bored today! ',
#  'home from a long day of work. i wore heels from 11am to 7pm. i must be crazy!! came right home to soak the feets. lol who wana rub em? ',
#  'Still at work  This entire week has felt like an extremely long and awful Monday!',
#  'Upgraded iPhone to 3.0 but seem to have weaker link to tamu wireless ',
#  'morning twitterland...off to work i go ',
#  "@Debbiebarnhill I'm such a plantaholic.... I spent several thousand $s the last few years planting at my brothers lake cabin - he sold it ",
#  'Trying to learn some &quot;PHOTOGRAPHY&quot; ',
#  "@KrisAllenmusic I'll be sure to vote for you in that competition.  A star with your name on it would go well with your Idol Trophy!",
#  'already miss baby donkey ',
#  "@kpsomotragos I have it on good authority that we'll be getting it around 3am. ",
#  'Just heard gun shots in my neighborhood!!! ',
#  'Just watched hella home movies with my aunt and uncle. I miss the days where our whole family got along ',
#  "I am sooo tired!! My eyes literally can't stay open ",
#  'I hate word challenge on facebook! ',
#  "is sad she couldn't go out with her girls tonight  It's been too long....",
#  'PACKING SUCKS! i miss my Lee ',
#  'O how i love you sammoons  o how i do. ',
#  'Wants a free doughnut, Krispy Kremes are so expensive, but 10 million times better than other doughnuts. ',
#  'new phone  tattoo on monday! Woo.. just had tea. yummy.',
#  'waiting for my hoe to come back ',
#  'i just cried a lot  im so over that all , and i cant hear it anymore...',
#  'Trying to get on facebook!!! ',
#  "I want to post lol cats on here but I can't ",
#  '@RobbieTaylor I have no comment about who won the game until this replay is completed. ',
#  "Thank you everyone. I seriously am I lucky guy to have such great and lovely friends. Let's keep in touch  chuckishere.com at #LAX",
#  'friday gimmick in the office  but always looking forward for the weekend!',
#  'TALK meeting tonight at Tampa Chamber at 6pm with @WOMlinda as guest speaker on Word of Mouth Marketing! Happy Hour after @ Tinatapas ',
#  'successfully obtained  visa entries to enter  and stay in the Royal Kingdom of Thailand! ',
#  'Downtown Disney ',
#  'missing my mom ',
#  'A little sad  pretty bad news and feel too much insecure about my playing.',
#  '@HuniB oOhwee naw i just been chillin tryna get use to this new work schedule of having to be at wrk @ 7... ',
#  "@juzgalvez Hahaha! Don't be scared. They need fresh minds and you're it. ",
#  'grandparents arrive tomorrow... good nite ',
#  'that was a good chat!  keep u posted guys...',
#  "@BrokenStruggle to much waffle &amp; not enough drinking going on. he's a less annoying version of numpty! &amp; he's not you which makes me ",
#  '@theclimbx3 i knooow  its the pizza girl episode xD &lt;3',
#  "Random drunk girl sitting by my car: &quot;Is that your man bag?&quot;  Me: &quot;Yes, that's my man bag.&quot;  BTW, its name is Butch  ",
#  'lots of cool ppl  ~~&gt; @actionchick @thewildjoker @walterdoc @JGDemas @amilya @williger  #followfriday',
#  'Alright this is my debute twitt  yay lol',
#  '@Spitphyre girls i am outta it then  my exams',
#  'Why do peep toe shoes hurt so bad ',
#  '@Alyssa_Milano do celebs get more characters than the rest of us? ',
#  'need to charge my mac... ',
#  'Keyshia cole loves bebe too!!! ',
#  '@dstarr I want my bed  x',
#  'Dang it....BRB....have to get the cake, candles and ice cream out and sing happy birthday to my niece. Sweet 16 ',
#  '@StiffValentine Olympus E-410.  Besides the recent digital lenses, I also got an old 50mm OM lens which mounts via a simple adapter.  ',
#  'is going to watch the brewer game, eat soup, play sims and sit in a vaporizer filled room. stupid cold. this sucks. ',
#  'Hmmm.... My whole body feels sore! ',
#  "@Venyadosae I'm sooo happy you'll get to re-take penguin pics! I collect penguin stuff and am a penguin FREAK! Can't wait to see ",
#  'My server has been going down lots lately, it makes me a sad WoW player  lol',
#  'how would you feel if @taylorswift13 was in a GoBernos video? eh eh ',
#  "@timdifford cheers, I spotted that - couldn't find it on the App Store though ",
#  'sore throat ',
#  "He'd go anywhere with me ",
#  '@LexiePixie your tarot twreading is next. ',
#  '@Bowl_the_Bunny lol love how we put some in stars: *some* haha...*crosses fingers* i hope you get more ',
#  'This tea taste like pure WATER!!!  Yuck!',
#  "sad that it's not my birthday anymore and that my balloon is deflating ",
#  'Great to get bk online, my own net was down ',
#  'St Andrews is scaring me. ',
#  'Finally done work YAY ',
#  '@DTatStar not nice  lol',
#  'i aint alive....im just breathing to death ',
#  'Sorry you missed it. Good night! ',
#  'oopss did that twice  D: im such a silly moo.',
#  '@acj525 mummmmmmmmmmm,  can you put the pizza in the oven ',
#  '@ibbypop haha yeeahh yeahh you know its only till 2:30 so its not too bad! ',
#  "@Jagusti shit! I thought it was months away  I'm not in Sheffield this weekend ",
#  "@Shadez mmm...i wouldn't mind li'l Katy's either.. ",
#  'On a JEW mood. Downloading Futures. Chase the Light naman mamaya. Haha. ',
#  "Wishes @kirstiealley a Happy Mother's Day! ",
#  'More rain due, ugh, going to a graduation today and was hoping the kids could go swimming ',
#  'woke up early today...dont wanna go to school tomorrow... ',
#  "I can't seem to fall asleep tonight ",
#  '#EU09 In 5 years we need a best coverage. World, take a look here, yes, here, Europe is moving ',
#  'That should give you happy thoughts ',
#  "@monzongo2009 OH NO!!!  Get well soon   I'm trying to get well myself in the midst of Merola.  Sending you virtual antibiotics ",
#  'Dam texts woke me up ',
#  "I could seriously go back to sleep  working 3-11 tonight w/ mitch...but toni won't be there...it's not the same, but i hope it's fun! ilu!",
#  'eatin an icecream ',
#  "@FifthSenseNYC I'll be giving the Mark Birley a wear later this week, even though I'm not a &quot;quiet man&quot;. ",
#  'happy birthday to andy hurley ',
#  'Hangin with my bestie suzi ',
#  ' FML.. today sucks.. i just hope the dance will bring my soul up.. i pray, but im still sad..i hateee todayyyyyy!!! &gt;;(',
#  'But I will follow ',
#  "I'm saying good bye to a good friend tonight... kinda sad ",
#  'my last nite in work for weeks.....ah im in such good humour ',
#  'My Sonic skills have not improved... Running, fine. Spinning, awesome. Jump from platform to platform? The fail whale grabs me ',
#  'saw a red balloon flying outside my window. somewhere out there, a kid must be crying because the wind blew his balloon away... ',
#  "Working today. Closing. 2 - 11. Missing out on Ming's birthday dinner/party. ",
#  '@JoshBkelley just wanted to say the youngstown girls miss you  .. &amp; what happened to tell it like it is on itunes? cant find it!',
#  "Ahhh...I finally don't have to keep 5 guys happy...I get waited on tonite ",
#  'hope you feel better mommy  I love you :X',
#  '@KandyChazer it is...but i was told i was gonna be entertained and i wasnt ',
#  "yay! just realized i'm not driving this trip and can do all the twittering!  ",
#  "@amf7 Thank you for reminding me! I actually have something in mind given the date. Hint, it's Star Trek related. ",
#  'We should have brought a flask with v0dka. Hahaha. ',
#  'Just got pulled over on 36. I am fucking terrified of cops. My headlights out I guess  mew.',
#  'gotta go check/console/convince 2 yo to stay in bed and that he actually WANTS to go to sleep... 20 min nap in car= past his sleep... ',
#  '@cali_g510 ok   I got you!',
#  "Changed the background on here. About to go watch 'Mary Shellys Frankenstein'.  Add: http://bit.ly/4Qhlv",
#  '@MANDY_EMMERSON I know you do, Go TEAM GB ',
#  '@sdministry Hey scott, Its Ashli from Shelby County, We met when Rick and Mick were in town. How you been? It been awhile ',
#  '@temptationdice why did my family decide to have a family gathering?  i see why you hate them. -.-',
#  '@kerryjor Happy Birthday!  Enjoy the cougar years - roar! ',
#  'I work 9-6 today with bitch boss ',
#  '  DD has pinkeye...not fun.',
#  '3 little birds pitch by my door step singing sweet songs of melodies pure &amp; true sayin dis is my message 2 you: dont worry about a thing ',
#  'Church of the Highlands @ 11:30 in the Bryant Conference Center! BE THERE!   ',
#  'Off to london biggin hill ',
#  'definitely just failed my exam ',
#  "@Burlesquetron oh sorry I didn't see this tweet further down sorry. unhappy DD = 4 champers 4 me + looking 4 hair dye in back of cupboard ",
#  "@laurie_pringle I mention it in the blog post. It's in Vancouver. ",
#  'I am soooo happy!!! ',
#  '@Itxi_Itx @th3maw  This is a great conversation.  What else might you do with your sheets during the act of love?  eh?  eh?  ',
#  "mark cubans doin handsprings right now- the &quot;punks and thugs&quot; are sinking.. but he's not looking forward to paying dirk's child support. ",
#  '@lovelyberries haha you can cuddle with me anytime ',
#  'had a lovely birthday.  http://plurk.com/p/xedq0',
#  '@judez_xo ugly kids there?  woahh where am i then. ',
#  "@canadianfamily The best thing about my Mother's Day was my son. And the card my husband got me 'from' our 5.5 week old son. ",
#  'Just got off the  ☎  Misery loves company..... Haha',
#  'ugh sdre isnt coming here  lame. today can suck my dick.',
#  '@andyclemmensen tv on mute cause its boring but then ipod with speakers on timer  now thats how its done.',
#  'TWO More weeks and its back to work. ',
#  'is healthy breakfast then back to geography revision ',
#  "off to sleep. GOOD NIGHT WORLD  hope it'll not rain tomorrow.",
#  "Kylie's being a bad girl today. ",
#  "@LaYdeeDeliSh he's definately a strong lil guy! ",
#  "I watched UP! This time I cried  It's really sad and hilarious ... That movie totally rocks!",
#  'just booked my driving test ',
#  "i've been working for more than 24 hours now ",
#  '@ddlovato I wish I was a celeb like you, Miley Cyrus, Selena Gomez, Taylor Swift, and all those pretty girls out there! ',
#  "I can't believe the last survivor of the Titanic died...that's really sad! ",
#  'Starting to wonder if my future landlord is crazy or prejudice against americans.. this may not end well ',
#  '@kiniaq and the reasons are never wrong my dear... they are absolutely lovely  wow',
#  "@lexia well done on all your reporting.  Haven't been vocal but have enjoyed and appreciated your work. Cheers lady. ",
#  "I would love the 85mm 1.2 .. but would settle for the 85mm 1.8. I'd also love a 1Dsmark3 for it to sit on ",
#  '@AngelIVXXX very good price ',
#  '@MrRathbone You have many friends here who will walk with you through the dark and the light. Smile ',
#  'soo hungry! hot dogs with all the fixings? sounds yummy ! ',
#  'is having a bad day - email not working properly and looks like the 10km run is off for me ',
#  '@officialnjonas you speak my name in chat? please?I am a big fan your...follow me? ',
#  'The Tonight Show w/ Conan was AWESOME!!! I missed that tall, pale, red-headed man! ',
#  "@Hail_Mary_Jane: never date anyone who's on twitter, then you can't tweet about how whack they are.&lt;----sooooooooo true ",
#  'I need someone to talk to!  Who can that be? ',
#  '@BrianMcnugget still your old joker kinda self...im glad...i kinda miss it ',
#  'un vot pe blogoree pls: http://bit.ly/ueUb6   Multumesc! ',
#  "Dear baby, I can't wait until your teething days are over. ",
#  "@ninasplayground LOL, I didn't know it was on  OF COURSE if watch that dumb bitches show ;-) like a train wreck... Can't stop watching ;)",
#  '@imPLastic ',
#  "BlackBerry troubles all over.. fortunately enough I don't have one! My HTC Touch works fine, for almost 2 years! ",
#  '@MeganBull how do you know how much your twitter profile is worth?? haha...or was that a joke? ',
#  "http://mobypicture.com/?yxykxt - I knew it from the start. It's a two year old t-shirt by now. Always makes me pleased to see though. ",
#  "I had Wendy's before this. That was a bad choice   http://twitpic.com/6vlkp",
#  '@cjm55 Thanks!  ',
#  'why do people not just try to understand instead of getting pissed off  when someone needs you, its cause they love you...',
#  '@Castiel_ yeah. totally. ',
#  "@Lumiel Aren't you sweet? ",
#  'CDC Vaccine Advisor Pockets $29 Million Promoting Vaccines -  http://is.gd/M7Q8 - MORE ELITIST SCUM VACCINATION PROFITEERING - Sorry ',
#  "@MissChriis i don't know how to celebrate yet. lol but i'm very excited about it. ",
#  '@windsorj Poor thing  Hope you feel brighter soon x',
#  'Ah. The perfect summer day was ruined by the rain. Too good to be true.  but its still hot as hell. I feel sticky and gross. Long day. Ha',
#  ' i gotta work today',
#  '@nowamunkie My pleasure. ',
#  'Blood Brothers was Amazing.  Got my program signed by the cast  Got a Picture with Sean Jones. ',
#  'bob to the top high school musical porno. ftw ',
#  "@DavidArchie I'm running a fever  If you gave me a shoutout I swear I'd get better! (HINTHINT!) HAHAHA.",
#  '@edicius during this Stanley Cup match up, yes, I am a Pens fan. ',
#  '@besz I will tell you on Thursday all about Tuesday, I promise. How bout I skip all this, and just eat the monkey for breakfast? ',
#  'I thought it was meant to be a hot summer  to mean rain doesnt mean hot.',
#  '@Wolfie75 Welcomes home  Glad you had a fabbo time!',
#  "doesn't know what to do with himself today... but might get some blonde put in his hair for summer ",
#  'kick  butt, Chuck has been renewed for a third season.  Sucks only 13 episodes though.    http://tr.im/lF45',
#  'just wants to get it over and done with. I miss working ',
#  '@Boy_Kill_Boy Anything for first class tix ',
#  "@Jason25329 Sorry to hear that  but hey, you're eating well at least!",
#  "Phew! Done rewriting the 1st bit of my results to order. Reread comments from bosses to ensure I'd incorporated them. Had. But sad now. ",
#  'morning tweeple  hope you all have a great monday',
#  'Home and off for hopefully, a sunny weekend ',
#  '@innocent_eyez26 OMG :o ahahaa. oh well, thats common there  hihii',
#  'packing up my room... ',
#  "CEO is on the floor today. Need to be careful while surfing today. It's all work and no play day. ",
#  'hitting the gym!  its bout time',
#  'Wife just left on a motorcycle ride. I still need to get my Washington plates , so I am at home, Drat! ',
#  '@TwilightilDawn Oh man I want palm trees and the beautiful ocean! Not cow town CO  Follow @peterfacinelli @billy_burke',
#  '#musicmonday King Blues My Bolder ',
#  "I have a 1,500-word deadline in 2 days, stacks of research materials are surrounding me, and I don't have a clue how to start  Need coffee",
#  "@gfalcone601 well at least you had a great time and thats what's important! ",
#  'Oh and more car FAIL, after all the work i had done Fri., the Check Engine light went on just as i got home last night ',
#  "@itwittmyclit I'm jealous. I wanna nerd out ",
#  '@PiKaHsSo Sup fam? Hope you have a GREAT weekend! Keep doing what u do, we appreciate u ',
#  'http://twitpic.com/4eg0i - Before his hair cut. I just wanna kiss that little face all day long ',
#  '@mike_rhodes r u romeo from somewhere? ',
#  'Only problem with Google Chrome: no foxkeh ',
#  "Figuring out how to live a life where I'm my own boss... fun ",
#  'CAN YOU SAY AFTER 30 HOURS OF TRAVELING IM FINALLY IN ARGENTINA?! yes! oh hello Buenos Aires, how i love you ',
#  '@dawnmcwilliams Saha ',
#  "I don't feel well at all. Dizziness and vomit. No fun ",
#  'I want to drink tonight,, want a cosmopolitan ',
#  '@dance2jeffreee I have already watch that video lol ',
#  "Everytime she stops talkin or replying for hours or days it is like she's leavin me all over again ",
#  'is off to work til 4! Happy Hump Day! ',
#  "@girl_alex ....  Hope you're okay?",
#  'i made 29 updates today, my record xD talk to you tomorrow bye ',
#  '@disco_di aww tell me about it!!! its just not the same  hope you have a better day',
#  '@SomeWriter Hey, great minds think alike! ',
#  "Mother's Day is a traditionally time for BBQ here ... unfortunately I don't like BBQ at all  ... but I am also not a mother ;-) ;-)",
#  "back from school w/ @_gerardo. Making a grocery run w/ @kellan_craddock before celebrating @chadachi's 22nd birthday with a barbeque. ",
#  'Summat to make your laugh today http://budurl.com/beckhams ',
#  'regretting not wearing sunscreen today, spent 6 hours walking round Kew Gardens during a mini heatwave. Healthy glow is an understatement ',
#  'Shot after shot. Alc is lying to me ',
#  '@kirstiealley Prizes are good! ',
#  'Everyone follow @JKitsJena because this twitter is fawked, pleeeeease and thank you ',
#  '@ the booptys crib watching chucky 3 with the little one my boopty aint feeling well ',
#  'im off from one job and now im off to my next one. i wish i was rich and didnt have to worry about money. but i have to cuz of my son.   ',
#  "@BT_broadband Ah, well, we're both in the same boat then. I switched because they were throttling the speed every single night. ",
#  'and @thedebbyryan http://www.debbyandchrisryanfansite.webs.com/ is WRONG tha page dont found  follow us -we r ur team TEAMofDEBBYRYAN',
#  '@tonyrobbins &quot;paradise is where I am.&quot; he also said ',
#  '@Guitargirl5595 yeah so now i am all bummed cause now i dont have college anymore ',
#  '@TomboyTigress  you told me you LIKED my marshmallow fish. *runs off crying*',
#  "is back at the hotel. wifi doesn't reach the room  http://plurk.com/p/rnauu",
#  'Im a very open girl and if you remain respectful, we will have a lot of fun  See my pics here http://sa9.us/HornySophie',
#  '@jaimeeashley i demand a picture of the red hair please and thankyou ',
#  'I will try to remember to Twitter from the George Strait concert ',
#  'going to take some photo and ride my whole new bike~~ ',
#  'good afternnon world althought the weather is bad i hate the rainny season ',
#  'Hai, anyone wanna hang? ',
#  "@victoriastevens yeah, i've started too ",
#  'I have got to bid ou all goodnight tweeps. Need to spend more QTwith @Mike103g the miniscule before he leaves for the week ',
#  'Tra la la la la!  might make a video later  see if i can be bothered ',
#  '@SamanthaOfUM lol that would tiiiiight but idk about money situation! ',
#  'I miss Ashley so much right now ',
#  "i can't believe this is all part of my detox (it is) because i was so fine and now i'm talking all core wounds! oh my god! jesus help me! ",
#  "is rockin' a minivan til the STi is ready. I miss it already ",
#  'Sooooo happy right now.  I &lt;3 my old high school friends.  Miss the boy already, though. ',
#  '@Young_SoulBlade hey, wassup? ',
#  "it seems that I'm going to lose the big #lgp2009's feast   I hope you enjoy it as much as I did!",
#  '@Shadows1990 Oh dear  should go out when your better ',
#  "@samantha247 Luckyyyy. I want to ding dong ditch with ya'll. Jealous. ",
#  "@Remy_Foster LOL I'm in your favourites 3 times!!! ",
#  '@Destini41 Have a safe trip, Desti, and have lots of fun!!! Hope you can tweet us a lot  And give @crystalchappell 4700 kisses from us',
#  '@ryanstar http://twitpic.com/6ub7v - Great view ',
#  'mmm taco doritos=heaven in my mouth ',
#  '@MandyyJirouxx morning already ',
#  "MTV Movie Awards yesterday: congrats Robert, Kristen, Miley and the Twilight's makers.  &lt;3",
#  'http://twitpic.com/8cwzd - the swimming pool of our hotel... that makes me dream of summer... in Vienna we have so far no summer ',
#  "Plans for today: Lunch with my darling Leila, getting my hair cut... Ok, that's the good part ",
#  '@cocababy202 hahaha it washed all the sick off of me. ',
#  "@SasaLoves I'm here princess!  Need to try to eat something before I drink. Still having waves of nausea - I should have napped ",
#  'Issue of Echelon?..Are they behind some Botnets also? ..you can watch...http://tinyurl.com/c8dns8  ah..but dont think like that ',
#  '@IsadoraR hooray for your english being done , but we are screwed for everything else ',
#  'No 12-hour coma today. I had a nightmare that shook me awake. ',
#  '@SenseiRAM We missed you ',
#  '@jonasbrothers dear nick jonas, please teach me how to play the glockenspiel. that is just about the coolest instrument name ever. ',
#  "3 hours till SD. longest trip ever. Never again. Ate a salad n pasta at dinner n couldn't even finish my pasta. ",
#  '#goodsex get the itus ',
#  "Watching ''The Cleaner'' &amp; taking care of wifey. She's sick. ",
#  'Drinking coffee ',
#  'Good morning everyone in this twitter world! Bangun jam segini mulu  http://myloc.me/23fl',
#  'Atlantis &amp; Hubble current location now is above Indonesia. Wave your hand guys, wave!  #fb',
#  'Another loser: i lost the game  http://tinyurl.com/cfz2lj',
#  'stuck at home in Temecula for the night  someone come save me pleaseeeeee!',
#  '@rhyanoutrageous thank you ',
#  "@MeiNg I'll settle for The Last Lecture by Randy Pausch instead. He is inspirational. ",
#  'going to bed.  i wish the hubby had more time off ',
#  'David started basic Wednesday and they took his phone for who knows how long... missing his voice and his kisses ',
#  '@Curiosafmmb  Dave yeah I prefer David actually!!. Yes he was Bill from Kill Bill. From what Ive hearded he had hung himslef ... ',
#  '@d33pak ya...but m missing my &quot;beeryani&quot; on the weekends ',
#  'so bored !  i want the Sims to hurry up and download',
#  '@persef I would gladly have him back in exchange for my sandwich though ',
#  '@Boyislost Ok im gona go  but I dont want to be close with anyone atm, sry if it takes a min to reply im at work so i have to hide twitter',
#  "@aeroform Naptime for me. Can't keep my eyes open. ",
#  'fed up with Windows, so Ubuntu Netbook Remix Edition is now on Kaylee ',
#  'I will never like getting up at 5 am  dumb work schedule.',
#  '@DVDeMm Want my Amazon box to arrive.  Probably Royal Mail playing football with it!',
#  '@dougiedaydream well yes but with a trilby, red wayfarers and a vintage casio watch in tow. i thought i looked good. ',
#  '@KellyOlexa it is like boxers under pants....It is to be FREE or not to BE FREE!!!! ',
#  "@GoCheeksGo i tried to vote but my phone sucks and wouldn't let me ",
#  '@mileycyrus voting has closed ',
#  "@SashaKane - That's a great mood to be in. Do you mind if I borrow it for this week?! ",
#  '@TheRealAD aw poor baby ',
#  'Photo: suneoke: saddens me that she’s taken  *tear* lol http://tumblr.com/xgo1z1owl',
#  'Then - Brad Paisley ',
#  'giving up on having a job this summer. Managers continue to fail to call me. Looks like its going to be a long broke year. ',
#  'Rumours OS 3 being released when Apple employees get into work (9am). Therefore 5pm uk time ',
#  'uni. home work ',
#  'enjoying my week off...now comes the busy part... ',
#  "@BecM49 i am, thanks (: i'll put you in mine ",
#  "Checking in  Good morning twitter fam! I'm in Miami, up bright and early, ready to hit the gym! xo",
#  "@NickHexum Please play Daisy Cutter+Jackpot+the rest of Uplifter in Atlanta. That'd be a pretty good 4th of July. ",
#  'Bank card fraud victim  $1,600 spent in 24hs. $400 at Celebrities, $400 at Richards on Richards and $800 at Safeway.',
#  'has to go. bye  http://plurk.com/p/z2e6x',
#  'taking a bath..and then go to the chruch!! ',
#  'not good, not good. ',
#  '@mr_billiam did you get your yabbies and your yobbos mixed up, or something?  ',
#  '@peanut2468 basically i was going 2 go 2 ur casa as soon as i got my license but u wernt home so... ',
#  'cold and flu tablets = EPIC FAIL. they dont even work ',
#  "@TheWayIRoll I don't know where is she... but I miss her  ahah goodnight honey! n.n",
#  'tired  and beleives early mornings should be illegal!',
#  '@dontforgetchaos aaah, sorry, you know i love you really!! hee hee  ;)',
#  '@FredroC1469 most of the time ',
#  "Oven has been on since 3:15... that's almost 3 hours!  3 loaves (1 cinnamon bread) &amp; 2.5 batches of rolls are baked. scones, not made yet ",
#  '@Em_Love yes, and FOH played at my friends school  how unfair?',
#  "man... I'll miss the JRuby on Google App Engine talk at #railsconf ",
#  'friday night and no 1 to go party wit im a loner in my own country ',
#  '@Stella_Holman no, orkut? ',
#  'oh no, i need new work shoes...i broke this one! ',
#  '@paulpuddifoot your pic/avatar is gone ',
#  "Ahh, I'm stuck... For my birthday I can either get a new phone (SMSNG Omnia) or I can get a Sky box in my room... HELP! Idk what to doooo ",
#  '@jmaxxz sssshhhhh....I run both at work ',
#  'Praying! I live like an hour away from where it happened. ',
#  "at work  then back to my baby's house ",
#  'going to 3 Horseshoes in Radnage for lunch with friends. Should be good! ',
#  "don't want to do my maths exam tomozz  iv left school for good  why make us come back and do them ",
#  '@KatiaDominos lmao yeah it is xD &amp; omg i put joe dancing to single ladies on my ipod!!! ',
#  "F to the Y to the I: I'm now home, but my stupid phone is still @ the office, so don't bother calling or texting me tonight. ",
#  '@HURM the way i have been feeling the last few days and nights... i think i have conficker... it tried playing opossum... it didnt work ',
#  "I am ill  And that when it's such good weather! Oh my english is so bad ",
#  'out of smokes and broke as a mothafuckerrr ',
#  'Sad that @mimigee will no longer be a fixture when i go visit NYC   Good luck at school!',
#  'About to Hang out with Sadey ',
#  "wtf happened 2 the sun?? its all alex's fault (quote &quot;Wot wud u do if it started pissin it down?&quot;) rain sucks ",
#  'at home, restingg ',
#  "U still waiting for still update! I've been sitting like a mad man all day! ",
#  "We can has OS 3 update?.......no we hasn't.   (shakes head and mopes away)",
#  'need rest but need Michelle ',
#  "@tpphotography bonkers isn't it? Pocket calculator + photocell somehow = ££££'s I've been looking for a reasonably priced one but no joy ",
#  '@PollyPocket3 do you hate us ? ',
#  'my car is dead........ what am i to do  Poor bug',
#  'Sorry, that last was for @popculturezoo Doctor who geek speak ',
#  '@backstreetboys Happy b-day Backstreeets!!!!Hope you go for many many moree!!Thank you for ur amazing music ',
#  '@whataboutadam My sis didnt get hers either ',
#  "Morning to all! Hope its a nicer day where you are compaired to here. It's going to rain all day and the next 2 days. ",
#  "@dannygokey Awww, Danny. Sorry I'm late!  Who wouldn't accept the offer to teach you uploading?",
#  "@RoseZag She's writing a book! It's good so far ",
#  "@mark_hadfield That's the other solution.  But it then stops genuine people from following you spontaneously based on your tweets.",
#  "@siamusic the land of replies is indeed a labourius place  at least you know you're loved!  xo",
#  'Wondering if I should take K to the release of Transformers 2 tomorrow. I hate crowds ',
#  'Only problem was lack of sauce The sauce is awesome, but not enough ',
#  '@divestoclimb It lets me through, but then gives a &quot;Sorry, no exact matches were found, but other tickets may still be available.&quot; error ',
#  '@Lifehigh83 I requested you. ',
#  'Having a well-deserved Guinness ',
#  "I can NOT believe my baby girl is 3!! I know I'm  lame b/c I'm actually sad about this!!I don't want her to grow up boo hoo ",
#  "@giloi2009 Yeah I got excited by seeing that changelog, then was bitterly disappointed there's no push notifications for Facebook ",
#  "Everybody's laughing at my neon day-glow argyle socks. ",
#  '@bowwow614 In your option i have to take tha nice guy ',
#  'sunny morning ',
#  "waiting for my dad to pick me up. we're gonna watch a movie  btw, new photos SOON! ",
#  'hates smart-arse rookie cops on power trips who pull you over and issue $189 fines ',
#  '@WSOPlive we appreciate the unscheduled coverage. keep it up and give the crew a raise ',
#  '@sharathpatali right on ! Just bought this new computer, will be mig easier to get code done ',
#  'i am so bored!!  well lets see i am writing my spanish paper and guess wht! schools over  FML!',
#  'woot! i have 77 points on my subway card! 75 points is a free foot long!  going to get it now!',
#  '@kimgoss i been saying that the past 2 weeks that i miss playing spades and drinkin chillin.. the good old days.. let me know baby ',
#  'No mini vacations for the moment  Starting a week with different / many things to do. Thank you God',
#  "i have no idea how i'm going to fix things with me and landon! i want things back to normal but i don't know how and if that is possible ",
#  '@Chinkerfly they never said anything interesting and i always had to wade through dozens of their tweets to get to people i cared about ',
#  ' well maybe next time my dreams with come true',
#  "BPHS Orchestra spring concert tomorrow night!  7:00 pm @ the PAC! Freefreefree! B there or B square! As Reuben says, &quot;It's instupituous!&quot;",
#  '@regalaffair hey you are up early ',
#  "@BevClement I don't think we talk much about Banks these days - not quite as respected as they once were ",
#  'Shout out to the Koblers... As Sure as the Dawn, here we go! Thanks again ',
#  "i've watched titanic hundreds of times but leo dying still gets me every time. ",
#  '@nickasaur hey nick  how are youu? x',
#  'Just edited about a million photos of cats, none of them for lolz. ',
#  "G'night,  I'll try to get on tomorrow! ",
#  'Good Morning Everyone... grinding the beans to make coconut macroon coffee anyone for a cup ',
#  "@emzsy I've come down with something. Had to come home from work.  feel shit. xox",
#  "It's brain-fried deadline time.  Dazed, unfocused, a bit of an out-of-body experience.  21 years ago, I would have paid to feel this way. ",
#  'im like really bored. staring at my arms..the autographs are on my hands are kinda fading away. but the arm parts r still der ',
#  '@yelyahwilliams why is franklin so sad?  everytime i hear it for some reason it makes me think of good times but im on the verge of cryin',
#  'Not looking forward to work AT ALL today. ',
#  "@SongzYuuup Heyyyy Trey! That's wassup! Take it over! Lol Have a good day in the VA ",
#  "@spencerpratt Congrats on the wedding  I'm glad you waited to have a nice traditional wedding!!",
#  "@dbdc We should be confident, especially with our home form. King Is a big miss though, but I've got lots of faith in Dawson. COYS! ",
#  '@Bran2110 eat a frosty for me ',
#  "@jodabone Cool, meet u there!  I'm gonna drive tho cause that's a long walk up the hill... lol. Before 9am they got Early Bird Specials.",
#  'just found out that the Boston Celtics lost to the Orlando Magic!! FUCK FUCK!! What a way to start the working week ',
#  "Feels partly responsible about the trouble in Iran cos his avatar STILL isn't green. ",
#  '@radna  is jesus christ also tweeting I wonder?',
#  "@TVdotcomAU Don't forget to watch @newinventors too! ",
#  'Sittin on a train platform waitin for a train. Quite possibly hav just failed another test ',
#  'Slightly better version. Posted the wrong one earlier. Sky is still blown out, sadly  Love the shot tho http://yfrog.com/7grxqj',
#  'were the ones who made you  x',
#  'FINALLY won a game of Settlers Of Catan. Also booked restaurant for birthday dinner. Life is good ',
#  'is dreading work tomoz, wonders if everything was done correctly at close :S gonna double check everything b4 hand ',
#  '@adaftscotslass Get 100 followers a day using www.tweeterfollow.com Once you add everyone you are on the train or pay vip ',
#  '@Nassira yep.yep. day job is kicking my butt at the moment. ',
#  'Together with michael. We just decided to cook some breakfast together. ',
#  '@MissCaseyB I know what you mean  rain sucks...',
#  '*sigh* more boring history to do ',
#  "@AIIisonIraheta What's up!? You rock! ",
#  "uploading photos from photoshoooot  guitarist is uber persistant..they're coming!",
#  'today was just SPLENDID!!! ',
#  "major focus issues in rehearsal today-wish i was outside so bad  cant wait to bbq hope 2nite !! come on 6 o'clock get here already",
#  "in Rome and it's raining ",
#  'Foiled again! Being dragged out by parents at a moments notice. I want to draw! ',
#  'I wish I could sleep ',
#  '@_Enigma__ I say stick to your guns...it will drive the women crazy. ',
#  '@LeahJKelly  that sucks.',
#  "@dreamergirl17 no  wayyy to much hw I gotta finish first. And it's way cold out!",
#  '@markmejia and @albertposis just made my day  luvv deemmm!!! haha',
#  '@MothersAnthem I have a request! Play Structure of a Heart tonite please ',
#  'i mean, i thought i was supposed to be like, excited and happy at this point, not stressed ',
#  '@mosesma You strike again with your article on twiter !   http://bit.ly/Ob9HA',
#  'is so tired from my workout..plus.. waiting to get some work soo bad.. UGH&gt;. i hate not having any money .. so much outcome and no income ',
#  "@brandonwalowitz Aww... I hope you change your mind about Twitter. If you ever do, I'll be here reading. ",
#  "http://digg.com/d1twJ0 sad  i was rootin' for her!",
#  "@RobinBrown78 You mean you're not a celeb? only followed you thinking you were related to Gordon silly me ",
#  "I just finished following some people. Gah, I'm so tired. Goodnight Tweetpeople. ",
#  '@jack_herer  Hahahaha, what snow??? Still nothing  ',
#  '@dages58 lol after this weekend yea ur right  text me cause im goin to 3rd and they dont have computers there  bye bye',
#  "@EdMunster I know don't remind me  ha",
#  '@giraffette special eddie pout is bloody fantastic. enjoyed it very much. thanks. ',
#  "@JELuttrull Thanks   Yeah, I was watching it a bit earlier, but my heart wasn't really in it.  Shocking, I know!",
#  "@sakurajewellery yeah, it's awful  he woke up doing this little cry'y mewing sound this morning, half asleep  How are you today Hun? X",
#  "We're watching Magic game at home... Hopefully they win so we could go to Orlando for Final  miss Orlando very much...",
#  "I don't want my sister to go back ",
#  'Feeelin Pretty Shitty. All She Had to Do Was Txt me once to remind me why i fell For Her. Why Must She Fuck With me like This ',
#  'I miss my Brandon ',
#  'Off to class! ',
#  "this is embarrassing who wants to set up texting via phone for me cuz i can't ",
#  "@vysh_doss Good stuff, ain't it? Yeah, you told me about Aamir. And you already know what Rendang is like reheated. ",
#  "@Dj_Phat awwwwwwwwww, that's how ur doin me now?? lol makin fun of my spelling??  i'ma beat u up when i see u! lol",
#  '@kareemdmapantz maybe tomorrow. hahaha i miss youuuu! you have a cam?! ohhh yer laptop! ',
#  '@xxkamm oh man you hardass  x3',
#  "Lazy day. Can't wait for maneater tonight. The book was awesome! ",
#  "I can finally go to bed now that I know who gets the gold logie,  im disappointed it wasn't rove though  ",
#  "@MSPMike Okay Mike, you have great photos, but can you take them right-side-up?  I'm getting a neck crick!  ",
#  "seems like a nice day-guess it's off to the park with my lil man ",
# ...
#  "omg. I haven't been on here in ages  Well, I'm starting to come back slowly but surely. ;3",
#  'I hate old RM cases, one just bit me ',
#  'Congrats @ashleytisdale!  @mileycyrus youll win for Last Song eventually, girl, dont worry!',
#  '@darker_artic yeah...maybe one day it will pay off.  have a nice day',
#  '@lenier you still giving it to the blues tonight tho? i reckon first try decides the game  #origin',
#  'oh yay torchwood has gone up to 20% its so slow ',
#  '@chadxhatred that sounds so redneck. then again, you ARE from kansas! hahaha ',
#  '@AlanCarr lookin forward to chattyman. the book was well  funny!   x',
#  'yessss @Jonasbrothers have done a video for Fly With Me ',
#  'hungry,tired,yet in a great mood! ',
#  'New tegan &amp; sara video, ROFL! Genius  How is everyone this...not so fine saturday?',
#  "At Meg's, Neck Ache From Plugged  xxx",
#  "I'm leaving work now. Trying to decide if I return on Sunday afternoon or Monday 4 am to meet a noon (UK time) deadline. ",
#  '@danspace Missy Higgins? Ugh, call the police! ',
#  '@jamshedwadia want to shave your head?? ',
#  '@SimonBob Nobody cares about grammar anymore. ',
#  "@stephenfry Oooo, Sound's good ",
#  '@cassandra2603 God what a cheery chat has he somehow can back into the news ? I know about Vera Drake hmm not pleasant  x',
#  'thanks for your support @stevebeasant ',
#  'Awww man, I woke up sick ',
#  'after smoking for 16 years , i have now not had a smoke for 4 weeks and 1 day  woooohooooo happy days',
#  'sooo im up and out! out with my peeps. i can tell its gonna be a early night. wishing i was caked up instead ',
#  "@NoraReed a year ago, after our move, we had tons and tons of packing material. Didn't save any, though ",
#  'i wanna go to the manchester apollo! ',
#  '@fionamccarthy Thanx hun ',
#  '@pinkymcsian YES bloody work ',
#  'http://twitpic.com/6v42q - Busy day at Genesis Bicycles in Easton, PA. Got in a great ride, now hubby has some shop work to do ',
#  "@shannamoakler http://twitpic.com/7s8p5 - Yeah that's the story of my life, and that pooor puppy ",
#  'Excuse me @btubquiz - can has interesting question please? Afternoon = bleh  [*nudge nudge* @lexiphanic]',
#  '@bryanchin87 @prakashdaniel I choke on Shisha  Safa still?',
#  '@xnattsx not top bad thanks  and you?',
#  "must get my butt out to see more shows/concerts. Last one I've been to was Spice Girls ",
#  "Oh no, was meant to go to the post office before it closed  hope they don't return my package",
#  "@MissMillions lololol...Good afternoon Miss MiL-Li-YONZ  Long night, ay? lol..Hope you're feeling better..",
#  '@vampirefreak101 Hey thanks a lot for you coverage in Motepulciano,  congrats girl!!!!  You make me so happy!!! ',
#  '@modus_operandi what is zaceed!? Also, nice tat @markdamgaard. ',
#  "@thehappyhours I'm so sorry ",
#  "quote of the day:people maybe won't remember what you said or did, but they will remember how you made them feel... ",
#  'My favorite part of the Tonight Show w/ Jay Leno is Jaywalking! Loved it! Will miss it! ',
#  'Just got home. About to leave for another grad party ',
#  '@zwalkk could you make yourself look like any more of a stoner punk?! sheesh.. let me remind u: 4/20- not a real holiday ',
#  'holy careful cropping, batman!    http://bit.ly/iNjhI',
#  '@writinginrain lol, i have too many favorites. thanks tho. ',
#  "My god this book is like listening to a record on repeat 170,000 times. I GET IT! AID TO AFRICA HASN'T &amp; WON'T HELP. Shut The Fuck Up! .. ",
#  '@WeirdKidd its never too early or too late ',
#  'Ugh,my laptop randomly stopped working...*Panick*-Oh no,what have i done?! ',
#  '@Mickie_1 thanks ',
#  '@minamic: Very true. ',
#  "hung with the boy. tomorrowwwwwwwww;; seeing Up with emma and Bribear!  i'm so excited.",
#  '@MissJoJoSmith Aw poor Subo ',
#  "@KickingBuckets paul has a huge yin. Like a baby's arm ",
#  "@LaMisty_Elite the mikey worm! It's a virus. Some kid hacks into ur acct. I don't know how 2 get rid of it! HELP!!! ",
#  'My ppl already at Carribean Fusion... heard its poppin... ',
#  "@nerdydork LOL! the thing that sucks for me is that I almost got my nose pierced today but I couldn't since i'm not 16 ",
#  "@romaiel Not a good time for a relationship.  Maybe a good time for a few flings though. He's young. She's young. They've got years.",
#  "still recovering from this weekend.  at least I'm off today...",
#  'Finally done all my coursewrok thank god! Time to chillax ',
#  'I have got such a sore stomach!!! At home sulking ',
#  'off for a BBQ this aft! ',
#  '@nantastiic she was in a coma after a car accident ',
#  'watchen the FRESH PRINCE OF BEL-AIR...still missen da hubby.. ',
#  'is asking, does Kris Allen has a Twitter account?  ',
#  "@tferraro @soverpeck @rhetter ACTUALLY...a potato is a tuber, but it's also known as a root vegetable...hey I'm Irish and know my spuds ",
#  '@NathanFillion im watching slither, its 4:30 am... im gunna have nightmares (worth it though lol great movie ',
#  'New on Etsy: Baseball stud earrings 7$  http://bit.ly/7S33G',
#  'Is going home late today after tiring loooooong day of work..... ',
#  '@boomx17 hey nothign have you checked out my website yet? ',
#  "Eating dinner with Tubby. He doesn't want any cow's tongue ",
#  "@zara19 I tried convincing my parents but it was no good. They don't want me to have a pet ",
#  '@3aneeda ma 36ach ma 3a6anee... the QUEEN of online shopping ',
#  "@sarah_cawood I've fed the rays off Grand Cayman. It was awesome ",
#  'JUST ME AND THESE FOUR WALLS AGAIN la la la la la..................... screams! i dont like thunder! ',
#  '@kd0bik not great this morning... got a stomach bug and was sick.... but doing better now, just laying in bed reading tweets! ',
#  'lol @rosiehancock Misunderestimated - whats wrong with that word? Also, been thinking bout your harsh truth and I have to say u are right ',
#  "@Theprettyartist I undestand the 'vicar types' comment now ",
#  '@lakersnation went 2 the 3rd one in grade7. dat was unforgettable. Maddog was dancing n everything.  i seriously want a parade dis year 2.',
#  "@catherinequinn9 wasn't doing anything particularly interesting just did the school run with the kiddies haha ",
#  "Sad I still cant seem to preorder a sim free/payg 3GS. Get the impression because I'm happy with £15 p/m instead of £30 I'll have to wait ",
#  "#followfriday wonderwoman @VelcroShoes is seriously the only follow I recommend she's ultra COOL!  enough said FOLLOW HER! ",
#  '@onesugarplease had an awesome weekend thanks, lots of miles on the bike!  hope your paella was good ',
#  'Sick daddy  send prayer his way',
#  '@worshipmeonly haha her reality show was pretty hilarious! ',
#  '+ICU+ the countdown begins! This Friday @ the Dragonfly! ICU on da dancefloor ',
#  "It's raining fucking harrrrrd. ",
#  '@ work  wanting to be at the fight with the rest of the guys.',
#  'Oooo Kardashians is on twice ',
#  "my sister's friend threw something at her head &amp; now it's bleeding. ",
#  '@tr74fpp Get 100 followers a day using www.tweeteradder.com Once you add everyone you are on the train or pay vip ',
#  'will get blackberry this sunday !!! ',
#  "The real estate market in Tulare county is so awesome right now!  Lots of buyer's &amp; not enough seller's...that is my problem right now!  ",
#  'Ok, apparently BOTH broadcast sites are killing my machine today, so broadcast called off. Sorry. ',
#  "@annaoboe I feel guilty for stealing your Hart tweet now  I don't think he will actually reply an answer though",
#  'great run tonight, now off to bed.. got to get up earlier to do my morning workout.. gonna be a long day tomorrow! got to go back to work ',
#  'On my way home, giving twin atlantic a miss. couldnt even get into the courtyard they were in. Thats twice ive missed them now! ',
#  "I know I've said this a million times before but...I really wish I wasn't allergic to hair dye ",
#  "@TheIntriguing1 I think it's more of a respitiry infection ",
#  "@nadalnews that's awful ",
#  '@fromtheold is that like the sequel to Mathematica?  I like a lot of what that guy does.  Seems to be a bona fide genius ',
#  '@KristenLihos want to come for dessert? ',
#  '@persiankiwi are you able to upload?  Otherwise, DM me ',
#  'This One Is For You - Free Marketing  | MangoOrange� http://tinyurl.com/p5nssr',
#  "keep having bad dreams these days...can't sleep well ",
#  'someone needs to bring be drugs. i wish to not have a sore throat any longer advil/tylenol seem not not work anymore ',
#  'happy at last! I have a picture already here in twitter,,, ',
#  "@pattiblaine Thanks! I'm trying to be a good patient ",
#  "Lastnight...FCKING SUCKED. I balled my eyes out. I miss Alex a lot  &amp; Marybeth's a bitch, and no, I'm not cencoring it, &amp; IDGAF.",
#  '@Edwardo01 awwww what a shame... cant get that picture to work ',
#  '@chrisaffair haha, I AM! but beware, its addicting ',
#  '@sweet_exile It really is quite a while!  Oh well, preview next week.',
#  'is really BORED!!!   http://plurk.com/p/13cyrd',
#  'im trying to convince alexis to stay up with me and ryan... i dont think its working so well! ',
#  '@mattfincham OH NO! not Tony  me sad now...',
#  "@ObsessedDiamond http://www.alexandraburkeofficial.com/forums/ click 'register' and you're away!  Don't forget to introduce yourself!",
#  'I swear there is something in this house that gives me THE worst headaches. ',
#  "@betsymaebartlet hurts even more when it's one of your best friends ",
#  "@do0dlebugdebz of course! Hehee live the manga. Tho I haven't read all of em'  one of the best shojo's EVER.",
#  'Thanks to the following for their awesome input: @StealingTheSun @ElizabethJoan @Schonste @ms_treesap @Beaudine  Thank yous &lt;3',
#  "@lolitztoeknee Awww, I'm sorry ",
#  "I'm driving my JellyBean and eating them at the same time LOL dassss igggnant but cuuuze ",
#  "#weekofwin I WON 2 sim cards  the blood the pain... I'm upset, feel robbed, but will continue for my search... N97box reviews to come ...",
#  'typical - went home and got changed.  put my rugby jumper on cos i thought it was a bit chilly and now the suns out ',
#  '@fashionismo ahhhh &quot;Sold Out&quot; ',
#  '23 or 24�C possible today. Nice ',
#  'is wishing you a lovely evening ',
#  '@FzMcFadden No worries, was looking for some retail activity  Thanks though',
#  "Stinkin' Rushkies score  1-1",
#  'Having way too many issues with my macbook pro. and its been 4 days since i got it.  Going to the store tomorrow.',
#  'Finally at homeeeeeeeeeeeeeeeeeee ',
#  "@garethb2  That's awesome, much love for the Gareth clan.",
#  '@keza34 @pob34 dont worry  @Dojie likes me really ',
#  '@JenBunnyy i read jon and kate filed divorce papers this afternoon  plus a possible custody battle...i feel so bad for those adorable kids',
#  "mandy doens't even like noodles! that's insane! ",
#  "Doing my hair with my icky thumb was a challenge. Accidentally banged it and it's started bleeding again ",
#  '@10rdBen That, Sir Abraham, is a fantastic approach. Thank you. ',
#  '@hotlantabuzz • *blushing* Me too, me too!!!  Hahahaha',
#  "hillsong tom. night, and dad's birthday! i wish i could see him on his bday though. ",
#  'hate my sis ',
#  "@Dribbby me too, its bad isn't it? doing well on your biology?  http://myloc.me/2hBr",
#  'I am so stressed ',
#  "@laurensbite What the....? I am so jealous! Where do we go for coverage? The &quot;go here for details&quot; wasn't clickable   Happy 4 you!!!!",
#  '#Haveyouever dated a guy who has a better looking brother...dam this always happens 2 me ',
#  '@ABBSound да. мой как раз пожрал, залез на шкаф и ?пит. орать ночью будет когда вы?пит?? ',
#  'UP in 3d movie date ',
#  "@VintageQueen1 ooooh, poor megan.  braces aren't that bad...",
#  'Damn you bbs there is no parking ',
#  'After 3 days of Safari 4 it seems as it finally grew up, and Firefox got fat and old ',
#  '@SaschaScarpulla i grew up with a siberian husky - spoiled me for life  love the name Valentino ',
#  "Any plans for this weekend? I'm going to Tokyo. YAY! I can't wait for shopping at Forever21!!  Gonna have a girls night. maybe;)",
#  '@mitchelmusso, but the previews are still awesome! ',
#  'At work, protecting the innocent weak from the guilty strong.  ',
#  "@jakeashley http://twitpic.com/6gcq4 - it's freaking awesome,haha love the monacle ",
#  'I think a homeless person took a bath in my mouth while I was sleeping ',
#  '@JD_Faery battery pushing will be a global phenomenon by 2012 trust me ',
#  '@erincampos the rain is in the jar. my stupidity included ',
#  "@Lipvixen Did your Curves Lady look like Summer Glau?  Knowing the answer is probably 'no' ",
#  'MMMMM.... i-ceam woo finished the preface of twific production ',
#  '@TheEllenShow I wish I was in Chicago ',
#  '@MarianSpier I want to come to the lecture so keep me posted ',
#  "Busy Busy weekend! Wow! Just finished a cake smash shoot for my son's 2nd birthday this week. Messy fun was had by all ",
#  "@MupNorth better than this place...ew   i just need to ask about the area..i really don't know london...oh also if they allow pets!!! ;)",
#  'i ask ah man why life so boring, if its because we poor ppl. he said YUP WE = NO JOB, NO MONEY = NO LIFE ',
#  '@BondiVet Sean has something for you, make sure he passes it on this week... ',
#  '@smilingme76 haha thanks ',
#  "@TJThyne Congrats on the renewal! I'm so excited that I get to keep my &quot;Hodgie&quot; for at least two more years! ",
#  "I'm home. . . . . ",
#  'Chilling in the garden ',
#  '@michiev why, thank you!  ',
#  "@umado Sadly I didn't have a Fred, or a Barney, or a Betty   Pics will be up on the BBC Cornwall website tomorrow!",
#  'CL Sweet ',
#  'feeling a little crafty. ',
#  'aww mann, my i-pod ear phones just bummed out. damm u apple!!! ',
#  '@jo_whit  Of course I do.',
#  'Summer of checking out colleges back east for &quot;T&quot;. Graduating class of 2010... Holy shit!  ',
#  '@wendywings hehe, better than nothing! What did you end up baking? ',
#  "@sherwinsteel and I still didn't get anything ",
#  '@nellleo If you have any Lotus Connections questions, let me know and I can answer them! ',
#  '@Pandaran Coffee, for now!  I probably have enough tequila in my liver to tide me over for a while ',
#  'I wish today was bagel day ',
#  '@bethbabezz did you have a good time at the party beth? ',
#  "@tommcfly  Tom, I guess you aren't photogenic, because you live is beautiful, perfect. you surprised me ",
#  'yay new addition to my sims family!! i dont want the baby to grow up ',
#  'Hair came out ok...short and sassy ',
#  'Download Opera Browser Free! Supporting Web Standards   http://bit.ly/w1WIR',
#  'hungova n feelin very sorry 4 maself!! had a wicked nyt wit the girlies tho! luv them soooooo much ',
#  '@rockinrose theres no such thing as chicargin ',
#  'siting on my TI lessons and finishing my movie.  peace kids, bless ya ^^',
#  '@stepheneyre Also ill, wishing to be at home having tea and soup. ',
#  '@KSBong  Scrabbles fun.. pac man makes me nervous to play.. those stupid little ghosts chasing you  are you playing scrabble by yourself?',
#  "All of the rollercoasters I make in rollercoaster tycoon are considered ultra-intense  I'm just too extreme for them...",
#  '@augustjoki @ryannielsen Office printer does not work for us- Canon MF4370dn - improperly installed driver error ',
#  "I've prepared My School Thingy. ",
#  "Feels like shit and can't get any sleep  meh",
#  '@jarich The latter ',
#  "@mactavish no worries   I'm told a Twitterific fix is just waiting for Apple to get around to approving it.",
#  "@DaisyReyes ohh ok! thanks! i'll add you tomorrow! because i'm too lazy to open my ym! hehe! ",
#  '@DENISE_RICHARDS you looked beautiful!! ',
#  'Walk is canceled today       It is pouring in Olive Branch.',
#  "@girrlonthewing Ha, well you'd be surprised at the things that will keep people busy for hours  and I want a kitty too ",
#  'Some dark clouds in #indiavotes #indiavotes09 #India #election : vote bank politics and dynastic politics / sycophants still rules. ',
#  '@wolfgnards awesome. Thanks for letting me know. I look forward to getting to know u. I am going to follow u now that I know who u are ',
#  'I left my heart @holdenbeach  Hoping to go back for a couple of days around the fourth',
#  'I wish I had the Sims 3 ',
#  ...]

# %%
# data['text_processed'] = data['text'].apply(clean_up_tokenize)

# %%
# data['text_processed'] = data['text_processed'].apply(stem_and_lemmatize)

# %%
# data['text_processed']

# %%
# data['text_processed'] = data['text_processed'].apply(remove_stopwords)

# %%
# from multiprocessing import Process

# procs = []
# # instantiating process with arguments
# for lists in list(data['text_processed']):
#     # print(name)
#     proc = Process(target=remove_stopwords, args=list(data['text_processed']))
#     procs.append(proc)
#     proc.start()

# # complete the processes
# for proc in procs:
#     proc.join()

# %%
data['text_processed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_processed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8312/3823426303.py in <module>
# ----> 1 data['text_processed']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'text_processed'

# %%
# processed_text = []
# for text in list(data['text']):
#     text1 = clean_up_tokenize(text)
#     text2 = stem_and_lemmatize(text1)
#     text3 = remove_stopwords(text2)
#     processed_text.append(text3)


# data['processed'] = processed_text

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
# your code here

# %%
# alllist = list(data['text_processed'])

# words = [word for sublist in alllist for word in sublist]
# unique = set(words)

# %%
import collections

c = collections.Counter(alllist)
c

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
