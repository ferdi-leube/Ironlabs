# %%
import numpy as np
import pandas as pd
import math
from itertools import permutations

# %%
word = 'IRONHACK'
l = [x for x in word]
print(l)
# Out:
# ['I', 'R', 'O', 'N', 'H', 'A', 'C', 'K']

# %%
list(permutations(l))
# Out:
# [('I', 'R', 'O', 'N', 'H', 'A', 'C', 'K'),
#  ('I', 'R', 'O', 'N', 'H', 'A', 'K', 'C'),
#  ('I', 'R', 'O', 'N', 'H', 'C', 'A', 'K'),
#  ('I', 'R', 'O', 'N', 'H', 'C', 'K', 'A'),
#  ('I', 'R', 'O', 'N', 'H', 'K', 'A', 'C'),
#  ('I', 'R', 'O', 'N', 'H', 'K', 'C', 'A'),
#  ('I', 'R', 'O', 'N', 'A', 'H', 'C', 'K'),
#  ('I', 'R', 'O', 'N', 'A', 'H', 'K', 'C'),
#  ('I', 'R', 'O', 'N', 'A', 'C', 'H', 'K'),
#  ('I', 'R', 'O', 'N', 'A', 'C', 'K', 'H'),
#  ('I', 'R', 'O', 'N', 'A', 'K', 'H', 'C'),
#  ('I', 'R', 'O', 'N', 'A', 'K', 'C', 'H'),
#  ('I', 'R', 'O', 'N', 'C', 'H', 'A', 'K'),
#  ('I', 'R', 'O', 'N', 'C', 'H', 'K', 'A'),
#  ('I', 'R', 'O', 'N', 'C', 'A', 'H', 'K'),
#  ('I', 'R', 'O', 'N', 'C', 'A', 'K', 'H'),
#  ('I', 'R', 'O', 'N', 'C', 'K', 'H', 'A'),
#  ('I', 'R', 'O', 'N', 'C', 'K', 'A', 'H'),
#  ('I', 'R', 'O', 'N', 'K', 'H', 'A', 'C'),
#  ('I', 'R', 'O', 'N', 'K', 'H', 'C', 'A'),
#  ('I', 'R', 'O', 'N', 'K', 'A', 'H', 'C'),
#  ('I', 'R', 'O', 'N', 'K', 'A', 'C', 'H'),
# ...

# %%
'''How many ways can you choose 3 people from a group of 17 for making the group projects teams?

17!/(3!*14!)
= 680

'''
# Out:
# 'How many ways can you choose 3 people from a group of 17 for making the group projects teams?\n\n17!/(3!*14!)\n= 680\n\n'

# %%
'''Let's imagine you need to organize the business processes in the coffee shop.  You know that each cup can be made from
10 possible ingridients. But it is not profitable to use more than 5 portions of ingridients at once. These ingridients
should not be unique (for example, you can put milk twice, and a chocolate onle). How many different variations of coffee
you can include to the menu?

(10+5-1)!/(10-1)*5!
= 80720640

'''
# Out:
# "Let's imagine you need to organize the business processes in the coffee shop.  You know that each cup can be made from\n10 possible ingridients. But it is not profitable to use more than 5 portions of ingridients at once. These ingridients\nshould not be unique (for example, you can put milk twice, and a chocolate onle). How many different variations of coffee\nyou can include to the menu?\n\n(10+5-1)!/(10-1)*5!\n= 80720640\n\n"

# %%
# '''Given an array of distinct integers, return all the possible permutations. You can return the answer in any order.
# The lenght of array and the integers are given by user and may vary.

# '''
# minn = int(input('Please input the minimum value of your array: '))
# maxx = int(input('Please input the maximum value of your array: '))
# array = np.arange(minn,maxx)
# result = set(permutations(array))
# Out:
# Please input the minimum value of your array: 2
# Please input the maximum value of your array: 100

# %%
'''Use intertools library to solve the following problem: Six books are lying on a table in front of you. How many ways
can you arrange the books, considering both the left-to-right order of the books and whether they’re set with the front
cover facing up or down?


'''
from itertools import permutations
books = [1,2,3,4,5,6]
combs = list(permutations(books, 6))
len(combs)*2
# Out:
# 1440
